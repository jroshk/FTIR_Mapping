# %% [markdown]
# #UV treated Silk pattern decomposition
#
# This notebook shows how to perform spectral deconvolution using the FTIR tool suite developed by KBI Biopharma.
#
# The spectral deconvolution tools utilize the scipy solvers to deconvolute second derivative or fourier self deconvolution spectra using a guassian peak model. There are three parameters per peak (mean, height and width), and thus 36 inputs are present for a 12 peak reference set. The default peak definitions `yang_h20_2015` has 14 peaks, and thus 42 input parameters are present. The parameter space is very large, and thus different gradient based solvers are likely to converge to slightly different local minima. A least squares approach using a linear loss function `rho(z) = z` was used for decomposition
#
# Modified by Jeff for his own vacation purposes

# %% [markdown]
# Setup, Import Code

# %%
# imports
# %matplotlib inline
import os
import pandas as pd
import numpy as np #import to take 2nd derivative as I don't think this occured, Jeff 2.28.2022 
import sys
sys.path.append("../")
import ftir.modeling.peak_fitting as peak_fitting
from ftir.modeling.buffer_subtraction import find_buffer_subtraction_constant, buffer_subtract
from ftir.modeling.peak_fitting import gaussian_minimize, gaussian_differential_evolution, gaussian_least_squares
from ftir.modeling.peak_fitting import secondary_structure, create_fit_plots, gaussian_list, sd_baseline_correction
# from ftir.modeling.peak_definitions import yang_h20_2015, dong_h2o_1990, yang_list
from ftir.io.utils import create_df_from_single_file

# %%
rawData_df = pd.read_csv(r"C:\Users\jrosh\ftir_data_analytics\data\QuartzCovered1onSpring.csv", header=None) 
# rawData_df.rename(columns={0: "wavenumber", 1: "1,1", 2:"1,2"}, inplace=True)
# len(rawData_df)
# # for x in rawData_df:
# #     rawData_df.rename(columns={0: "wavenumber", 1:"1,1", 2:"1,2"}, inplace=True)

# sample_names = list(rawData_df.columns)[1:]
# rawData_df[(rawData_df['wavenumber'] > 1450) & (rawData_df['wavenumber'] < 1820)].plot.line(x='wavenumber', y='1,1').invert_xaxis()
# #can I plot multiple spectra and label them?
# rawData_df[(rawData_df['wavenumber'] > 1450) & (rawData_df['wavenumber'] < 1820)].plot.line(x='wavenumber', y=['1,1','1,2']).invert_xaxis()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2184/2971690667.py in <module>
# ----> 1 rawData_df = pd.read_csv(r"C:\Users\jrosh\ftir_data_analytics\data\QuartzCovered1onSpring.csv", header=None)
#       2 # rawData_df.rename(columns={0: "wavenumber", 1: "1,1", 2:"1,2"}, inplace=True)
#       3 # len(rawData_df)
#       4 # # for x in rawData_df:
#       5 # #     rawData_df.rename(columns={0: "wavenumber", 1:"1,1", 2:"1,2"}, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\jrosh\\ftir_data_analytics\\data\\QuartzCovered1onSpring.csv'

# %%
# imports
# %matplotlib inline
import os
import pandas as pd
from ftir.modeling.buffer_subtraction import find_buffer_subtraction_constant, buffer_subtract
from ftir.modeling.peak_fitting import gaussian_minimize, gaussian_differential_evolution, gaussian_least_squares
from ftir.modeling.peak_fitting import secondary_structure, create_fit_plots, gaussian_list, sd_baseline_correction
from ftir.modeling.peak_definitions import yang_h20_2015, dong_h2o_1990
from ftir.io.utils import create_df_from_single_file

# get the data
#mydata= pd.read_csv("C:\\Users\\Deepanshu\\Documents\\file1.csv")

#os.getcwd()
#raw_data_filename = os.path.abspath("./20191009_nsm_Icatibant/2Der/23_0 2Der.txt")
# rawData_df = pd.read_csv("C:\Users\jrosh\FTIRpythonAttempt\FTIRrawspectraUVmaskLeftside.csv") #pd.read_csv(raw_data_filename, header=None)
#rawData_df.rename(columns={0: "Wavenumber", 1: "first_point"}, inplace=True)
#sample_names = list(rawData_df.columns)[1:]
#rawData_df[(rawData_df['Wavenumber'] > 1450) & (rawData_df['Wavenumber'] < 1820)].plot.line(x='Wavenumber', y='first_point').invert_xaxis()

# %%
rawData_df.shape
# Out:
# (2381, 400)

# %%
#dim1 = np.array([1:1:25])
dims = []
for i in range(1,400):
    dims.append(f"cols{i}")
    # for j in range(1,26):
    #     dims.append(str([i,j]))

# %%
len(dims)
# Out:
# 399

# %%
column_names = list(['wavenumber'])+ dims

# %%
type(column_names[3])
# Out:
# str

# %%
beta_sheet_df = pd.DataFrame(rawData_df.values, columns = column_names)

# %%
beta_sheet_df.head()
# Out:
#    wavenumber    cols1    cols2    cols3    cols4    cols5    cols6    cols7  \
# 0  3998.51641  0.00562 -0.01114  0.00542  0.00856  0.00611 -0.01270 -0.01142
# 1  3997.08837  0.00557 -0.01115  0.00538  0.00851  0.00605 -0.01270 -0.01145
# 2  3995.66033  0.00551 -0.01120  0.00532  0.00845  0.00598 -0.01273 -0.01148
# 3  3994.23229  0.00545 -0.01129  0.00526  0.00840  0.00592 -0.01279 -0.01153
# 4  3992.80425  0.00541 -0.01135  0.00523  0.00836  0.00588 -0.01283 -0.01158
#
#      cols8    cols9  ...  cols390  cols391  cols392  cols393  cols394  \
# 0 -0.01064  0.00768  ... -0.01150 -0.01012  0.01041 -0.01112 -0.00953
# 1 -0.01066  0.00766  ... -0.01161 -0.01024  0.01033 -0.01122 -0.00961
# 2 -0.01068  0.00759  ... -0.01173 -0.01036  0.01023 -0.01138 -0.00969
# 3 -0.01068  0.00752  ... -0.01181 -0.01044  0.01015 -0.01152 -0.00973
# 4 -0.01067  0.00745  ... -0.01186 -0.01049  0.01010 -0.01159 -0.00975
#
#    cols395  cols396  cols397  cols398  cols399
# 0 -0.01156 -0.01428 -0.01165 -0.01057 -0.01049
# 1 -0.01168 -0.01440 -0.01177 -0.01066 -0.01060
# 2 -0.01181 -0.01453 -0.01190 -0.01075 -0.01075
# 3 -0.01191 -0.01462 -0.01199 -0.01080 -0.01088
# 4 -0.01197 -0.01464 -0.01204 -0.01082 -0.01098
#
# [5 rows x 400 columns]

# %% [markdown]
# ## Baseline correction
#
# Rubberband baseline correction was done, and the spectra was flipped over the y-axis. The spectra was also narrowed to focus only on the amide I region.

# %%
# imports
# %matplotlib inline
import os
import pandas as pd
from ftir.modeling.buffer_subtraction import find_buffer_subtraction_constant, buffer_subtract
from ftir.modeling.peak_fitting import gaussian_minimize, gaussian_differential_evolution, gaussian_least_squares
from ftir.modeling.peak_fitting import secondary_structure, create_fit_plots, gaussian_list, sd_baseline_correction
from ftir.modeling.peak_definitions import yang_h20_2015, dong_h2o_1990
from ftir.io.utils import create_df_from_single_file

# get the data
#mydata= pd.read_csv("C:\\Users\\Deepanshu\\Documents\\file1.csv")

# #os.getcwd()
# #raw_data_filename = os.path.abspath("./20191009_nsm_Icatibant/2Der/23_0 2Der.txt")
# rawData_df = pd.read_csv("C:\Users\jrosh\FTIRpythonAttempt\FTIRrawspectraUVmaskLeftside.csv") #pd.read_csv(raw_data_filename, header=None)
# rawData_df.rename(columns={0: "Wavenumber", 1: "first_point"}, inplace=True)
# sample_names = list(rawData_df.columns)[1:]
# rawData_df[(rawData_df['Wavenumber'] > 1450) & (rawData_df['Wavenumber'] < 1820)].plot.line(x='Wavenumber', y='first_point').invert_xaxis()

# %%
corrected_beta_sheet = []
for cols_ in beta_sheet_df.columns[1:]:
    #print(str(cols_))
    corrected_beta_sheet.append(sd_baseline_correction(beta_sheet_df, cols=[cols_], flip=False, method='rubberband', bounds=(1725, 1595)))

# %%
corrected_beta_sheet
# Out:
# [    wavenumber     cols1
#  0   1723.64618  0.000000
#  1   1722.21814  0.000037
#  2   1720.79010  0.000043
#  3   1719.36206  0.000000
#  4   1717.93402  0.000000
#  ..         ...       ...
#  86  1600.83461  0.017338
#  87  1599.40657  0.012391
#  88  1597.97852  0.008104
#  89  1596.55048  0.004017
#  90  1595.12244  0.000000
#
#  [91 rows x 2 columns],
#      wavenumber     cols2
#  0   1723.64618  0.000000
#  1   1722.21814  0.000027
#  2   1720.79010  0.000023
#  3   1719.36206  0.000000
#  4   1717.93402  0.000000
#  ..         ...       ...
#  86  1600.83461  0.017417
#  87  1599.40657  0.012470
#  88  1597.97852  0.008173
#  89  1596.55048  0.004057
#  90  1595.12244  0.000000
#
#  [91 rows x 2 columns],
#      wavenumber     cols3
#  0   1723.64618  0.000000
#  1   1722.21814  0.000047
#  2   1720.79010  0.000053
#  3   1719.36206  0.000000
#  4   1717.93402  0.000000
#  ..         ...       ...
#  86  1600.83461  0.017797
#  87  1599.40657  0.012725
#  88  1597.97852  0.008333
#  89  1596.55048  0.004132
#  90  1595.12244  0.000000
#
#  [91 rows x 2 columns],
#      wavenumber     cols4
#  0   1723.64618  0.000000
#  1   1722.21814  0.000057
#  2   1720.79010  0.000063
#  3   1719.36206  0.000000
#  4   1717.93402  0.000000
#  ..         ...       ...
#  86  1600.83461  0.017939
#  87  1599.40657  0.012812
#  88  1597.97852  0.008385
#  89  1596.55048  0.004157
#  90  1595.12244  0.000000
#
#  [91 rows x 2 columns],
#      wavenumber     cols5
#  0   1723.64618  0.000000
#  1   1722.21814  0.000067
#  2   1720.79010  0.000073
#  3   1719.36206  0.000000
#  4   1717.93402  0.000000
#  ..         ...       ...
#  86  1600.83461  0.017960
#  87  1599.40657  0.012872
#  88  1597.97852  0.008435
#  89  1596.55048  0.004197
#  90  1595.12244  0.000000
#
#  [91 rows x 2 columns],
#      wavenumber     cols6
#  0   1723.64618  0.000000
#  1   1722.21814  0.000067
#  2   1720.79010  0.000063
#  3   1719.36206  0.000000
#  4   1717.93402  0.000000
#  ..         ...       ...
#  86  1600.83461  0.017785
#  87  1599.40657  0.012756
#  88  1597.97852  0.008367
#  89  1596.55048  0.004159
#  90  1595.12244  0.000000
#
#  [91 rows x 2 columns],
#      wavenumber     cols7
#  0   1723.64618  0.000000
#  1   1722.21814  0.000053
#  2   1720.79010  0.000037
#  3   1719.36206  0.000000
#  4   1717.93402  0.000000
#  ..         ...       ...
#  86  1600.83461  0.017913
#  87  1599.40657  0.012842
#  88  1597.97852  0.008432
#  89  1596.55048  0.004201
#  90  1595.12244  0.000000
#
#  [91 rows x 2 columns],
#      wavenumber     cols8
#  0   1723.64618  0.000000
#  1   1722.21814  0.000067
#  2   1720.79010  0.000073
#  3   1719.36206  0.000000
#  4   1717.93402  0.000000
#  ..         ...       ...
#  86  1600.83461  0.017979
#  87  1599.40657  0.012887
#  88  1597.97852  0.008455
#  89  1596.55048  0.004202
#  90  1595.12244  0.000000
#
#  [91 rows x 2 columns],
#      wavenumber     cols9
#  0   1723.64618  0.000000
#  1   1722.21814  0.000073
#  2   1720.79010  0.000077
#  3   1719.36206  0.000000
#  4   1717.93402  0.000000
#  ..         ...       ...
#  86  1600.83461  0.018154
#  87  1599.40657  0.013021
#  88  1597.97852  0.008547
#  89  1596.55048  0.004254
#  90  1595.12244  0.000000
#
#  [91 rows x 2 columns],
#      wavenumber    cols10
#  0   1723.64618  0.000000
#  1   1722.21814  0.000070
#  2   1720.79010  0.000070
#  3   1719.36206  0.000000
#  4   1717.93402  0.000000
#  ..         ...       ...
#  86  1600.83461  0.018223
#  87  1599.40657  0.013092
#  88  1597.97852  0.008592
#  89  1596.55048  0.004271
#  90  1595.12244  0.000000
#
#  [91 rows x 2 columns],
#      wavenumber    cols11
#  0   1723.64618  0.000000
#  1   1722.21814  0.000077
#  2   1720.79010  0.000073
#  3   1719.36206  0.000000
#  4   1717.93402  0.000000
#  ..         ...       ...
#  86  1600.83461  0.018057
#  87  1599.40657  0.012955
#  88  1597.97852  0.008493
#  89  1596.55048  0.004222
#  90  1595.12244  0.000000
#
#  [91 rows x 2 columns],
#      wavenumber    c
#  90  1595.12244  0.000000
#
#  [91 rows x 2 columns]]

# %%
#corrected_df = sd_baseline_correction(beta_sheet_df, cols=['cols1'], flip=False, method='rubberband', bounds=(1725, 1595))
corrected_beta_sheet[3].plot.line(x='wavenumber', y=corrected_beta_sheet[3].columns[1]).invert_xaxis()

# %%
#this is in peak_fitting but I'm putting it here too because Ritwika did
import math
#import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt
#this below doesn't work!!!
#from ftir.modeling.peak_definitions import hu_Kaplan_Cebe_2006_actual
hu_Kaplan_Cebe_2006_rounded = {
    'means': [1610, 1619, 1625, 1633,  1642, 1650, 1659, 1667, 1679, 1692, 1700],
    'uncertainties': [(1605, 1615), (1616, 1621), (1622, 1627), (1628, 1637),
                      (1638, 1646), (1647, 1655), (1656, 1662), (1663, 1670),
                      (1671, 1685), (1686, 1696), (1697, 1703)],
    'relative_uncertainties': [5, 2.5, 2.5, 4.5, 4, 4, 3, 3.5, 7, 5, 3],
    'assignments': ['(Tyr) side chains/aggregate strands', 'aggregate beta-strand/beta_sheet(weak)', 
                    'intermolecular beta_sheet (strong)', 'intramolecular beta_sheet (strong)^b',
                    'random coils/extended', 'random coils', 'alpha-helices', 'turns',
                    'turns', 'turns', 'intermolecular beta_sheets (weak)']
}

six_peak = {
    'means': [1610, 1625,  1646, 1659, 1679, 1700],
    'uncertainties': [(1605, 1615), (1616, 1637),
                      (1638, 1646), (1647, 1662), (1663, 1696), (1697, 1703)],
    'relative_uncertainties': [5, 10.5, 4, 7.5, 16.5, 3],
    'assignments': ['(Tyr) side chains/aggregate strands', 'aggregate beta-strand/beta_sheet',
                    'random coils', 'alpha-helices', 'turns', 'intermolecular beta_sheets (weak)']
}


from scipy import optimize
from scipy.spatial import ConvexHull

def gaussian_least_squares_(df, col, peaks= six_peak,
                           peak_width=15, params=dict()): # originally was yang_h20_2015,

    def fun(p, x, y):
        """ Minimizing across parameter space p, for a given range, x"""
        return gaussian_sum(x, *p) - y

    data = np.array(pd.concat([df.iloc[:,0], df[col]], axis=1))
    heights = guess_heights_(df, col, peaks['means'], gain=1.0)
    width = peak_width
    lb = list()
    ub = list()
    guess = list()

    # Make 1-D array for optimization func definition above
    for mean, bound, height in zip(peaks['means'], peaks['uncertainties'],
                                   heights):
        lb.extend([0, bound[0], 0])
        ubh = np.inf if height <= 0 else height
        ub.extend([ubh, bound[1], peak_width*1])
        guess.extend([height*0.95, mean, peak_width])

    args = [fun, np.array(guess)]
    params['args'] = (data[:, 0], data[:, 1])
    params['bounds'] = (np.array(lb), np.array(ub))
    res = optimize.least_squares(*args, **params)

    areas = list()
    for i in range(0, len(res.x), 3):
        height = res.x[i]
        width = res.x[i+2]
        area = gaussian_integral(height, width)
        areas.append(area)
    return areas, res

def guess_heights_(df, col, center_list, gain=0.95):
    """ Determines guesses for the heights based on measured data.

    Function creates an integer mapping to the measured frequencies, and then
    creates an initial peak height guess of gain*actual height at x=freq*. A
    Default of 0.95 seems to work best for most spectra, but can be change to
    improve convergence.

    Parameters
    ----------
    df : Dataframe
        Dataframe containing the measured absorbance data

    col : string or integer
        Column index for the absorbance data being fit. Accepts either index
        or string convention.

    center_list : iterable of integers
        An iterable of integer peak positions used to find the experiment
        absorbance at a given wavenumber. I.e, the heights are returned at the
        center values in this iterable

    gain : number (optional)
        Fraction of the measured absorbance value to use determine the initial
        guess for the peak height. The value Default value is 0.95, and thus
        by default, all initial peak guesses are 95% of the peak max.

    """
    heights = []
    freq_map = {}
    for i in df.iloc[:,0]:
        j = math.floor(i)
        freq_map[j] = float(df[col].get(df.iloc[:,0] == i))
    print(freq_map)
    # pdb.set_trace()
    for i in center_list:
        height = freq_map[i]
        heights.append(gain*height)
    return heights

# %%
# find_deriv(dfcorrected_df, flip, window_length=5)
# deriv_df.plot(kind='line',x=deriv_df.columns[0],y=deriv_df.columns[1:], figsize=(15,10))

# %%
corrected_beta_sheet[0].columns[1]
# Out:
# 'cols1'

# %%
len(corrected_beta_sheet)
# Out:
# 399

# %%
structs =[]
gaussian_data = []
for i in range(0,len(corrected_beta_sheet)):
    
    sample = corrected_beta_sheet[i].columns[1]
    #print("Analyzing {}".format(corrected_df[i].columns[1]))
    area, res = gaussian_least_squares(corrected_beta_sheet[i], corrected_beta_sheet[i].columns[1], peak_width=15, 
                                    peaks=six_peak, params={'loss':'linear'})
    structs.append(secondary_structure(area, six_peak))
    gaussian_list_data = gaussian_list(corrected_beta_sheet[i]['wavenumber'], *res.x)
    gaussian_data.append(gaussian_list_data)
    #plt = create_fit_plots(corrected_df[i], sample, gaussian_list_data)
    #plt.show()

#print(structs[0])

# %%
len(structs)
# Out:
# 399

# %%
structs
# Out:
# [{'alpha-helices': 0.28356147415924915,
#   'random coils': 0.330863321269414,
#   'turns': 0.04201884293252149,
#   'intermolecular beta_sheets (weak)': 0.002684185043292407,
#   'aggregate beta-strand/beta_sheet': 0.2707676076540785,
#   '(Tyr) side chains/aggregate strands': 0.07010456894144464},
#  {'alpha-helices': 0.2839789331464562,
#   'random coils': 0.31959155795337035,
#   'turns': 0.048361449181995295,
#   'intermolecular beta_sheets (weak)': 0.003457257710608286,
#   'aggregate beta-strand/beta_sheet': 0.27575403255304914,
#   '(Tyr) side chains/aggregate strands': 0.06885676945452048},
#  {'alpha-helices': 0.2838698913102,
#   'random coils': 0.32758374326662565,
#   'turns': 0.042355771156236025,
#   'intermolecular beta_sheets (weak)': 0.0031661304180919513,
#   'aggregate beta-strand/beta_sheet': 0.2731329956227154,
#   '(Tyr) side chains/aggregate strands': 0.06989146822613077},
#  {'alpha-helices': 0.2844148145876006,
#   'random coils': 0.30218766095632343,
#   'turns': 0.056088422962226644,
#   'intermolecular beta_sheets (weak)': 0.0036752138499304915,
#   'aggregate beta-strand/beta_sheet': 0.28374521885832177,
#   '(Tyr) side chains/aggregate strands': 0.06988866878559723},
#  {'alpha-helices': 0.2828877732451634,
#   'random coils': 0.31980898996202556,
#   'turns': 0.047162389883476735,
#   'intermolecular beta_sheets (weak)': 0.0028174641072431163,
#   'aggregate beta-strand/beta_sheet': 0.2773558240654758,
#   '(Tyr) side chains/aggregate strands': 0.0699675587366152},
#  {'alpha-helices': 0.28838454413330783,
#   'random coils': 0.31500959543970086,
#   'turns': 0.047552550978337896,
#   'intermolecular beta_sheets (weak)': 0.003120338561098086,
#   'aggregate beta-strand/beta_sheet': 0.2778267526527235,
#   '(Tyr) side chains/aggregate strands': 0.06810621823483187},
#  {'alpha-helices': 0.27531746658731815,
#   'random coils': 0.30271253278972554,
#   'turns': 0.06307410175898824,
#   'intermolecular beta_sheets (weak)': 0.0042014178790993496,
#   'aggregate beta-strand/beta_sheet': 0.2865761190297129,
#   '(Tyr) side chains/aggregate strands': 0.0681183619551558},
#  {'alpha-helices': 0.2849172587396273,
#   'random coils': 0.313221585004098,
#   'turns': 0.04982045158192793,
#   'intermolecular beta_sheets (weak)': 0.003328435853131932,
#   'aggregate beta-strand/beta_sheet': 0.28096885032755453,
#   '(Tyr) side chains/aggregate strands': 0.06774341849366021},
#  {'alpha-helices': 0.2987939177505022,
#   'random coils': 0.30987512375344134,
#   'turns': 0.042496100409358216,
#   'intermolecular beta_sheets (weak)': 0.0028991225533306244,
#   'aggregate beta-strand/beta_sheet': 0.27650397261894466,
#   '(Tyr) side chains/aggregate strands': 0.06943176291442295},
#  {'alpha-helices': 0.2974119883648279,
#   'random coils': 0.31260236558744703,
#   'turns': 0.04203620132653157,
#   'intermolecular beta_sheets (weak)': 0.002711648704272106,
#   'aggregate beta-strand/beta_sheet': 0.2759941942710868,
#   '(Tyr) side chains/aggregate strands': 0.06924360174583458},
#  {'alpha-helices': 0.27950022432580407,
#   'random coils': 0.3254239295012158,
#   'turns': 0.04592128088973131,
#   'intermolecular beta_sheets (weak)': 0.0030069843042455206,
#   'aggregate beta-strand/beta_sheet': 0.2778980532675586,
#   '(Tyr) side chains/aggregate strands': 0.06824952771144467},
#  {'alpha-helices': 0.2806295271819017,
#   'random coils': 0.32157196941281835,
#   'turns': 0.04651687849867872,
#   'intermolecular beta_sheets (weak)': 0.0026780871112951896,
#   'aggregate beta-strand/beta_sheet': 0.28014008874001506,
#   '(Tyr) side chains/aggregate strands': 0.06846344905529096},
#  {'alpha-helices': 0.2595483105168353,
#   'random coils': 0.2908711441063559,
#   'turns': 0.07676671743189543,
#   'intermolecular beta_sheets (weak)': 0.004616557487809537,
#   'aggregate beta-strand/beta_sheet': 0.3326898999606584,
#   '(Tyr) side chains/aggregate strands': 0.0355073704964454},
#  {'alpha-helices': 0.2714343887115183,
#   'random coils': 0.313223690156965,
#   'turns': 0.0574520698170062,
#   'intermolecular beta_sheets (weak)': 0.003640764892097109,
#   'aggregate beta-strand/beta_sheet': 0.28717217562789804,
#   '(Tyr) side chains/aggregate strands': 0.0670769107945152},
#  {'alpha-helices': 0.2467017479446371,
#   'random coils': 0.294887682781469,
#   'turns': 0.0832568644793753,
#   'intermolecular beta_sheets (weak)': 0.00519476473085688,
#   'aggregate beta-strand/beta_sheet': 0.3314265303269674,
#   '(Tyr) side chains/aggregate strands': 0.03853240973669431},
#  {'alpha-helices': 0.28574925589508654,
#   'random coils': 0.3136180438511964,
#   'turns': 0.04691215461659833,
#   'intermolecular beta_sheets (weak)': 0.0031295746438732793,
#   'aggregate beta-strand/beta_sheet': 0.28565113533525377,
#   '(Tyr) side chains/aggregate strands': 0.06493983565799169},
#  {'alpha-helices': 0.2671864661177754,
#   'random coils': 0.3094845208350489,
#   'turns': 0.0611848658466933,
#   'intermolecular beta_sheets (weak)': 0.00385512014144247,
#   'aggregate beta-strand/beta_sheet': 0.29547773213471135,
#   '(Tyr) side chains/aggregate strands': 0.06281129492432867},
#  {'alpha-helices': 0.278966791097025,
#   'random coils': 0.31142400682478233,
#   'turns': 0.04970170386810124,
#   'intermolecular beta_sheets (weak)': 0.003164600111888075,
#   'aggregate beta-strand/beta_sheet': 0.30501367795909723,
#   '(Tyr) side chains/aggregate strands': 0.05172922013910618},
#  {'alpha-helices': 0.2546562248999741,
#   'random coils': 0.3002252204873478,
#   'turns': 0.07211974600240884,
#   'intermolecular beta_sheets (weak)': 0.004721049758806136,
#   'aggregate beta-strand/beta_sheet': 0.3230172312213758,
#   '(Tyr) side chains/aggregate strands': 0.045260527630087186},
#  {'alpha-helices': 0.27695078288205244,
#   'random coils': 0.3082965305835901,
#   'turns': 0.05202406352407799,
#   'intermolecular beta_sheets (weak)': 0.0035453889645360235,
#   'aggregate beta-strand/beta_sheet': 0.2981740111116022,
#   '(Tyr) side chains/aggregate strands': 0.061009222934141315},
#  {'alpha-helices': 0.2770244441837785,
#   'random coils': 0.3182718160771006,
#   'turns': 0.051617968949186285,
#   'intermolecular beta_sheets (weak)': 0.002856725572511275,
#   'aggregate beta-strand/beta_sheet': 0.2795821322014993,
#   '(Tyr) side chains/aggregate strands': 0.07064691301592396},
#  {'alpha-helices': 0.24154073887713567,
#   'random coils': 0.30426586093213387,
#   'turns': 0.0809058825997405,
#   'intermolecular beta_sheets (weak)': 0.005310584310682829,
#   'aggregate beta-strand/beta_sheet': 0.3279987778543875,
#   '(Tyr) side chains/aggregate strands': 0.03997815542591954},
#  {'alpha-helices': 0.2817481813445459,
#   'random coils': 0.3518442807366608,
#   'turns': 0.047369832731162596,
#   'intermolecular beta_sheets (weak)': 0.005009272804677049,
#   'aggregate beta-strand/beta_sheet': 0.30970568546323657,
#   '(Tyr) side chains/aggregate strands': 0.004322746919717104},
#  {'alpha-helices': 0.28259859775606894,
#   'random coils': 0.3479690174640203,
#   'turns': 0.04747708658565184,
#   'intermolecular beta_sheets (weak)': 0.0052707634673297005,
#   'aggregate beta-strand/beta_sheet': 0.3124967881632596,
#   '(Tyr) side chains/aggregate strands': 0.004187746563669682},
#  {'alpha-helices': 0.28055577608357124,
#   'random coils': 0.3543675451934713,
#   'turns': 0.04826448387812391,
#   'intermolecular beta_sheets (weak)': 0.005268989550138755,
#   'aggregate beta-strand/beta_sheet': 0.3071285115994292,
#   '(Tyr) side chains/aggregate strands': 0.004414693695265447},
#  {'alpha-helices': 0.2818500948156508,
#   'random coils': 0.3535822373903501,
#   'turns': 0.047939018878074106,
#   'intermolecular beta_sheets (weak)': 0.0052001715215725,
#   'aggregate beta-strand/beta_sheet': 0.30708530587332356,
#   '(Tyr) side chains/aggregate strands': 0.004343171521028873},
#  {'alpha-helices': 0.28729376421712693,
#   'random coils': 0.3391836112579257,
#   'turns': 0.052351405549530175,
#   'intermolecular beta_sheets (weak)': 0.006017172115352731,
#   'aggregate beta-strand/beta_sheet': 0.31058861258559967,
#   '(Tyr) side chains/aggregate strands': 0.004565434274464718},
#  {'alpha-helices': 0.28339572016112535,
#   'random coils': 0.3483133156197818,
#   'turns': 0.047725813718881065,
#   'intermolecular beta_sheets (weak)': 0.005121501979704338,
#   'aggregate beta-strand/beta_sheet': 0.31111625038057417,
#   '(Tyr) side chains/aggregate strands': 0.004327398139933358},
#  {'alpha-helices': 0.2858595609210151,
#   'random coils': 0.3490899636039906,
#   'turns': 0.049584793581009784,
#   'intermolecular beta_sheets (weak)': 0.005269831834719986,
#   'aggregate beta-strand/beta_sheet': 0.30527180793770975,
#   '(Tyr) side chains/aggregate strands': 0.0049240421215548695},
#  {'alpha-helices': 0.283337989392287,
#   'random coils': 0.3495600612365868,
#   'turns': 0.05206610510486248,
#   'intermolecular beta_sheets (weak)': 0.005883756255072804,
#   'aggregate beta-strand/beta_sheet': 0.30455514470856415,
#   '(Tyr) side chains/aggregate strands': 0.004596943302626747},
#  {'alpha-helices': 0.28793684424721055,
#   'random coils': 0.33611896188913004,
#   'turns': 0.05424732950883732,
#   'intermolecular beta_sheets (weak)': 0.006497446005255191,
#   'aggregate beta-strand/beta_sheet': 0.31116392681159416,
#   '(Tyr) side chains/aggregate strands': 0.004035491537972876},
#  {'alpha-helices': 0.28053695308021637,
#   'random coils': 0.35357806329113645,
#   'turns': 0.048759222424238476,
#   'intermolecular beta_sheets (weak)': 0.0052736272257598695,
#   'aggregate beta-strand/beta_sheet': 0.30774397393043,
#   '(Tyr) side chains/aggregate strands': 0.004108160048218799},
#  {'alpha-helices': 0.2779018050963626,
#   'random coils': 0.35965874144709564,
#   'turns': 0.048813803495917546,
#   'intermolecular beta_sheets (weak)': 0.006104445461678667,
#   'aggregate beta-strand/beta_sheet': 0.30311326620152484,
#   '(Tyr) side chains/aggregate strands': 0.0044079382974207965},
#  {'alpha-helices': 0.2798118624125361,
#   'random coils': 0.36180988727026403,
#   'turns': 0.04977399217264727,
#   'intermolecular beta_sheets (weak)': 0.005479814762971809,
#   'aggregate beta-strand/beta_sheet': 0.2980916991406403,
#   '(Tyr) side chains/aggregate strands': 0.005032744240940457},
#  {'alpha-helices': 0.28523114157024226,
#   'random coils': 0.3511441434990667,
#   'turns': 0.049905467990789106,
#   'intermolecular beta_sheets (weak)': 0.005304466685508417,
#   'aggregate beta-strand/beta_sheet': 0.30349166231204056,
#   '(Tyr) side chains/aggregate strands': 0.004923117942352999},
#  {'alpha-helices': 0.2891749109608845,
#   'random coils': 0.33624561310730133,
#   'turns': 0.05521582048635977,
#   'intermolecular beta_sheets (weak)': 0.00556202524045092,
#   'aggregate beta-strand/beta_sheet': 0.3094627543512712,
#   '(Tyr) side chains/aggregate strands': 0.0043388758537321135},
#  {'alpha-helices': 0.28325473651147304,
#   'random coils': 0.3496750087603011,
#   'turns': 0.04870217027100961,
#   'intermolecular beta_sheets (weak)': 0.0046798261106258095,
#   'aggregate beta-strand/beta_sheet': 0.30943326479866795,
#   '(Tyr) side chains/aggregate strands': 0.004254993547922509},
#  {'alpha-helices': 0.2827123587685336,
#   'random coils': 0.3520144298842154,
#   'turns': 0.049141254941319094,
#   'intermolecular beta_sheets (weak)': 0.005012105012009936,
#   'aggregate beta-strand/beta_sheet': 0.3066515064298971,
#   '(Tyr) side chains/aggregate strands': 0.004468344964024793},
#  {'alpha-helices': 0.30459297665541707,
#   'random coils': 0.40632428094911627,
#   'turns': 0.030279531068733104,
#   'intermolecular beta_sheets (weak)': 0.004416386624409152,
#   'aggregate beta-strand/beta_sheet': 0.21375689964589273,
#   '(Tyr) side chains/aggregate strands': 0.04062992505643178},
#  {'alpha-helices': 0.2841343796546471,
#   'random coils': 0.4688254279304266,
#   'turns': 0.041256858994101024,
#   'intermolecular beta_sheets (weak)': 0.005146139593733001,
#   'aggregate beta-strand/beta_sheet': 0.180714135631732,
#   '(Tyr) side chains/aggregate strands': 0.019923058195360287},
#  {'alpha-helices': 0.27547489199684777,
#   'random coils': 0.3303620315176497,
#   'turns': 0.04901100021939013,
#   'intermolecular beta_sheets (weak)': 0.001989929430183698,
#   'aggregate beta-strand/beta_sheet': 0.27432458223102746,
#   '(Tyr) side chains/aggregate strands': 0.06883756460490142},
#  {'alpha-helices': 0.28393527535580176,
#   'random coils': 0.3078474845188844,
#   'turns': 0.04979083316513288,
#   'intermolecular beta_sheets (weak)': 0.0026050399994324764,
#   'aggregate beta-strand/beta_sheet': 0.30231812952333365,
#   '(Tyr) side chains/aggregate strands': 0.05350323743741486},
#  {'alpha-helices': 0.2847220463684024,
#   'random coils': 0.3480525290350568,
#   'turns': 0.04679487326458926,
#   'intermolecular beta_sheets (weak)': 0.0040635554469086975,
#   'aggregate beta-strand/beta_sheet': 0.3121620156762672,
#   '(Tyr) side chains/aggregate strands': 0.0042049802087755885},
#  {'alpha-helices': 0.27642618531960134,
#   'random coils': 0.31210731332789976,
#   'turns': 0.0522281706392404,
#   'intermolecular beta_sheets (weak)': 0.00243523906528364,
#   'aggregate beta-strand/beta_sheet': 0.31890018773863976,
#   '(Tyr) side chains/aggregate strands': 0.03790290390933513},
#  {'alpha-helices': 0.28567751801034186,
#   'random coils': 0.3135979069835631,
#   'turns': 0.0463673507721593,
#   'intermolecular beta_sheets (weak)': 0.0023965338803526364,
#   'aggregate beta-strand/beta_sheet': 0.3047388629511059,
#   '(Tyr) side chains/aggregate strands': 0.04722182740247733},
#  {'alpha-helices': 0.2720536260545871,
#   'random coils': 0.31775841070799155,
#   'turns': 0.05397907117125704,
#   'intermolecular beta_sheets (weak)': 0.002779153284685453,
#   'aggregate beta-strand/beta_sheet': 0.2900695596512625,
#   '(Tyr) side chains/aggregate strands': 0.06336017913021642},
#  {'alpha-helices': 0.25071902743943186,
#   'random coils': 0.30460470973558307,
#   'turns': 0.07572748567481649,
#   'intermolecular beta_sheets (weak)': 0.003486082501661788,
#   'aggregate beta-strand/beta_sheet': 0.33262051973584456,
#   '(Tyr) side chains/aggregate strands': 0.03284217491266232},
#  {'alpha-helices': 0.2786973311386429,
#   'random coils': 0.31854891993635903,
#   'turns': 0.04948332900088431,
#   'intermolecular beta_sheets (weak)': 0.0024266222654412478,
#   'aggregate beta-strand/beta_sheet': 0.2947895584132171,
#   '(Tyr) side chains/aggregate strands': 0.05605423924545517},
#  {'alpha-helices': 0.2571307087972131,
#   'random coils': 0.30957225905210795,
#   'turns': 0.06958270016942703,
#   'intermolecular beta_sheets (weak)': 0.0034293306961443166,
#   'aggregate beta-strand/beta_sheet': 0.3125587788252959,
#   '(Tyr) side chains/aggregate strands': 0.04772622245981179},
#  {'alpha-helices': 0.267352983628004,
#   'random coils': 0.32038341398790254,
#   'turns': 0.055231027891869434,
#   'intermolecular beta_sheets (weak)': 0.0025284814135306537,
#   'aggregate beta-strand/beta_sheet': 0.3120789035833922,
#   '(Tyr) side chains/aggregate strands': 0.04242518949530116},
#  {'alpha-helices': 0.2775731801788519,
#   'random coils': 0.31732197807385387,
#   'turns': 0.05038920235881361,
#   'intermolecular beta_sheets (weak)': 0.0021591925469405127,
#   'aggregate beta-strand/beta_sheet': 0.3154501740549519,
#   '(Tyr) side chains/aggregate strands': 0.037106272786588464},
#  {'alpha-helices': 0.2537061235448705,
#   'random coils': 0.3051931664447769,
#   'turns': 0.07425065597208037,
#   'intermolecular beta_sheets (weak)': 0.0031636336084134376,
#   'aggregate beta-strand/beta_sheet': 0.3262622492431274,
#   '(Tyr) side chains/aggregate strands': 0.037424171186731435},
#  {'alpha-helices': 0.26605423258289235,
#   'random coils': 0.2989495420918336,
#   'turns': 0.06816091840198901,
#   'intermolecular beta_sheets (weak)': 0.002995806126309274,
#   'aggregate beta-strand/beta_sheet': 0.3221487574748864,
#   '(Tyr) side chains/aggregate strands': 0.04169074332208938},
#  {'alpha-helices': 0.28304550446453147,
#   'random coils': 0.3179689671888906,
#   'turns': 0.047162676579172794,
#   'intermolecular beta_sheets (weak)': 0.0021601679253325824,
#   'aggregate beta-strand/beta_sheet': 0.30279378003554996,
#   '(Tyr) side chains/aggregate strands': 0.04686890380652248},
#  {'alpha-helices': 0.2723062719945205,
#   'random coils': 0.32000485457603783,
#   'turns': 0.05219709978200577,
#   'intermolecular beta_sheets (weak)': 0.002202757872897847,
#   'aggregate beta-strand/beta_sheet': 0.3097782592076334,
#   '(Tyr) side chains/aggregate strands': 0.0435107565669046},
#  {'alpha-helices': 0.27743521039917574,
#   'random coils': 0.31541747463036246,
#   'turns': 0.050313092643451976,
#   'intermolecular beta_sheets (weak)': 0.0019896072153217357,
#   'aggregate beta-strand/beta_sheet': 0.31972251911936006,
#   '(Tyr) side chains/aggregate strands': 0.035122095992328003},
#  {'alpha-helices': 0.2890343358997697,
#   'random coils': 0.2948373472501305,
#   'turns': 0.05520646688202899,
#   'intermolecular beta_sheets (weak)': 0.0022361405107633545,
#   'aggregate beta-strand/beta_sheet': 0.3182215206870668,
#   '(Tyr) side chains/aggregate strands': 0.04046418877024061},
#  {'alpha-helices': 0.2892280922172167,
#   'random coils': 0.3366452062333372,
#   'turns': 0.04463489243633759,
#   'intermolecular beta_sheets (weak)': 0.002820170862954703,
#   'aggregate beta-strand/beta_sheet': 0.3227607254763051,
#   '(Tyr) side chains/aggregate strands': 0.003910912773848781},
#  {'alpha-helices': 0.29124971984866216,
#   'random coils': 0.01042123589061275,
#   'turns': 0.3438349592434413,
#   'intermolecular beta_sheets (weak)': 0.1432437378550524,
#   'aggregate beta-strand/beta_sheet': 0.09898959453798299,
#   '(Tyr) side chains/aggregate strands': 0.11226075262424833},
#  {'alpha-helices': 0.4037282285399076,
#   'random coils': 0.35352723597947655,
#   'turns': 0.09496906970670785,
#   'intermolecular beta_sheets (weak)': 0.0011389975607322053,
#   'aggregate beta-strand/beta_sheet': 0.13440811601865582,
#   '(Tyr) side chains/aggregate strands': 0.012228352194520013},
#  {'alpha-helices': 0.28529652490655655,
#   'random coils': 0.30562814303527414,
#   'turns': 0.055191763675934744,
#   'intermolecular beta_sheets (weak)': 0.001741667402024968,
#   'aggregate beta-strand/beta_sheet': 0.326023683618719,
#   '(Tyr) side chains/aggregate strands': 0.026118217361490594},
#  {'alpha-helices': 0.28892388618603215,
#   'random coils': 0.3438193216145567,
#   'turns': 0.04559813179777542,
#   'intermolecular beta_sheets (weak)': 0.00284035859026328,
#   'aggregate beta-strand/beta_sheet': 0.31447203527728773,
#   '(Tyr) side chains/aggregate strands': 0.004346266534084615},
#  {'alpha-helices': 0.28826122132525833,
#   'random coils': 0.34997167776953597,
#   'turns': 0.04832721816937217,
#   'intermolecular beta_sheets (weak)': 0.0033072819688865157,
#   'aggregate beta-strand/beta_sheet': 0.30557053920893723,
#   '(Tyr) side chains/aggregate strands': 0.0045620615580097236},
#  {'alpha-helices': 0.28664121180468033,
#   'random coils': 0.35373855211792377,
#   'turns': 0.048541562992937194,
#   'intermolecular beta_sheets (weak)': 0.0030453809896975026,
#   'aggregate beta-strand/beta_sheet': 0.30313750582701676,
#   '(Tyr) side chains/aggregate strands': 0.004895786267744457},
#  {'alpha-helices': 0.2869715453051723,
#   'random coils': 0.3530495246017667,
#   'turns': 0.04860769027705796,
#   'intermolecular beta_sheets (weak)': 0.0030657334343900523,
#   'aggregate beta-strand/beta_sheet': 0.3035783050972738,
#   '(Tyr) side chains/aggregate strands': 0.004727201284339276},
#  {'alpha-helices': 0.28657321000878583,
#   'random coils': 0.35411630382339215,
#   'turns': 0.04929936682691312,
#   'intermolecular beta_sheets (weak)': 0.002826845927953351,
#   'aggregate beta-strand/beta_sheet': 0.3023694050950891,
#   '(Tyr) side chains/aggregate strands': 0.004814868317866343},
#  {'alpha-helices': 0.2883038688879332,
#   'random coils': 0.35126767344435356,
#   'turns': 0.04853324188735522,
#   'intermolecular beta_sheets (weak)': 0.0029220441538884206,
#   'aggregate beta-strand/beta_sheet': 0.304072992924201,
#   '(Tyr) side chains/aggregate strands': 0.004900178702268677},
#  {'alpha-helices': 0.2883084020905767,
#   'random coils': 0.353910188046157,
#   'turns': 0.04922855654398423,
#   'intermolecular beta_sheets (weak)': 0.002777900257001191,
#   'aggregate beta-strand/beta_sheet': 0.30054323231623264,
#   '(Tyr) side chains/aggregate strands': 0.0052317207460484605},
#  {'alpha-helices': 0.2874126539515932,
#   'random coils': 0.3535114337772026,
#   'turns': 0.05076128875629072,
#   'intermolecular beta_sheets (weak)': 0.0030515612500840164,
#   'aggregate beta-strand/beta_sheet': 0.30057508939376315,
#   '(Tyr) side chains/aggregate strands': 0.004687972871066292},
#  {'alpha-helices': 0.2846483959240038,
#   'random coils': 0.3592983644546686,
#   'turns': 0.0500378240982116,
#   'intermolecular beta_sheets (weak)': 0.0031893554363137903,
#   'aggregate beta-strand/beta_sheet': 0.29773124359617054,
#   '(Tyr) side chains/aggregate strands': 0.005094816490631649},
#  {'alpha-helices': 0.28881518184371396,
#   'random coils': 0.3526002008482223,
#   'turns': 0.04915099082315934,
#   'intermolecular beta_sheets (weak)': 0.00312258144005017,
#   'aggregate beta-strand/beta_sheet': 0.30117907419867884,
#   '(Tyr) side chains/aggregate strands': 0.005131970846175375},
#  {'alpha-helices': 0.28870573471458094,
#   'random coils': 0.3483739382197912,
#   'turns': 0.04903160157566451,
#   'intermolecular beta_sheets (weak)': 0.002992487045510562,
#   'aggregate beta-strand/beta_sheet': 0.3062241191671934,
#   '(Tyr) side chains/aggregate strands': 0.004672119277259371},
#  {'alpha-helices': 0.28787036681094236,
#   'random coils': 0.3587327905525211,
#   'turns': 0.04999726779121103,
#   'intermolecular beta_sheets (weak)': 0.002629033262171957,
#   'aggregate beta-strand/beta_sheet': 0.2953534454880143,
#   '(Tyr) side chains/aggregate strands': 0.005417096095139214},
#  {'alpha-helices': 0.2842940980094842,
#   'random coils': 0.36302875487136926,
#   'turns': 0.051095912951330744,
#   'intermolecular beta_sheets (weak)': 0.00311406747593123,
#   'aggregate beta-strand/beta_sheet': 0.2931365410011781,
#   '(Tyr) side chains/aggregate strands': 0.005330625690706484},
#  {'alpha-helices': 0.29265268136007433,
#   'random coils': 0.3538794501991545,
#   'turns': 0.05322901679434062,
#   'intermolecular beta_sheets (weak)': 0.0026590741337282836,
#   'aggregate beta-strand/beta_sheet': 0.2921835026585894,
#   '(Tyr) side chains/aggregate strands': 0.0053962748541128555},
#  {'alpha-helices': 0.29285548548028534,
#   'random coils': 0.34927467257441813,
#   'turns': 0.052547626743118636,
#   'intermolecular beta_sheets (weak)': 0.0026477767764775135,
#   'aggregate beta-strand/beta_sheet': 0.297255602175842,
#   '(Tyr) side chains/aggregate strands': 0.005418836249858313},
#  {'alpha-helices': 0.2875121291758354,
#   'random coils': 0.35112940202980675,
#   'turns': 0.04796557421295938,
#   'intermolecular beta_sheets (weak)': 0.0023827007849829603,
#   'aggregate beta-strand/beta_sheet': 0.306285436265768,
#   '(Tyr) side chains/aggregate strands': 0.004724757530647522},
#  {'alpha-helices': 0.29175606726499675,
#   'random coils': 0.34109666351752405,
#   'turns': 0.047019398611921955,
#   'intermolecular beta_sheets (weak)': 0.001724817918565241,
#   'aggregate beta-strand/beta_sheet': 0.3131666567723539,
#   '(Tyr) side chains/aggregate strands': 0.00523639591463813},
#  {'alpha-helices': 0.28894958700073053,
#   'random coils': 0.35457879080976135,
#   'turns': 0.05077452544134863,
#   'intermolecular beta_sheets (weak)': 0.002609210778061345,
#   'aggregate beta-strand/beta_sheet': 0.2976479662039467,
#   '(Tyr) side chains/aggregate strands': 0.00543991976615127},
#  {'alpha-helices': 0.29554435811400454,
#   'random coils': 0.3809757132409635,
#   'turns': 0.06832016192010874,
#   'intermolecular beta_sheets (weak)': 0.002695482034987478,
#   'aggregate beta-strand/beta_sheet': 0.2466487446033183,
#   '(Tyr) side chains/aggregate strands': 0.0058155400866175795},
#  {'alpha-helices': 0.2726585284386483,
#   'random coils': 0.3285419338583027,
#   'turns': 0.05108434608403457,
#   'intermolecular beta_sheets (weak)': 0.0010932446504580274,
#   'aggregate beta-strand/beta_sheet': 0.3232251742264539,
#   '(Tyr) side chains/aggregate strands': 0.023396772742102744},
#  {'alpha-helices': 0.288942648524931,
#   'random coils': 0.3435161220909193,
#   'turns': 0.04510746287975815,
#   'intermolecular beta_sheets (weak)': 0.001570300454309565,
#   'aggregate beta-strand/beta_sheet': 0.3158784549988545,
#   '(Tyr) side chains/aggregate strands': 0.004985011051227604},
#  {'alpha-helices': 0.28672892925839044,
#   'random coils': 0.3536305117296135,
#   'turns': 0.04823518521493648,
#   'intermolecular beta_sheets (weak)': 0.0021602034364543088,
#   'aggregate beta-strand/beta_sheet': 0.3044195627309891,
#   '(Tyr) side chains/aggregate strands': 0.004825607629616098},
#  {'alpha-helices': 0.28955646325545914,
#   'random coils': 0.349812103845124,
#   'turns': 0.0482609154716188,
#   'intermolecular beta_sheets (weak)': 0.0016640182397585437,
#   'aggregate beta-strand/beta_sheet': 0.30569072130598735,
#   '(Tyr) side chains/aggregate strands': 0.005015777882052255},
#  {'alpha-helices': 0.2881118682387745,
#   'random coils': 0.3497479777881946,
#   'turns': 0.04790543825129921,
#   'intermolecular beta_sheets (weak)': 0.0018041285455871632,
#   'aggregate beta-strand/beta_sheet': 0.3074560625860084,
#   '(Tyr) side chains/aggregate strands': 0.004974524590135966},
#  {'alpha-helices': 0.2863808753374092,
#   'random coils': 0.35404917462646224,
#   'turns': 0.048274972774300484,
#   'intermolecular beta_sheets (weak)': 0.0017756227869450132,
#   'aggregate beta-strand/beta_sheet': 0.30455451726553806,
#   '(Tyr) side chains/aggregate strands': 0.004964837209345085},
#  {'alpha-helices': 0.2889076769053243,
#   'random coils': 0.3453582818755547,
#   'turns': 0.04680711666909334,
#   'intermolecular beta_sheets (weak)': 0.0018128944073305953,
#   'aggregate beta-strand/beta_sheet': 0.3124216470045839,
#   '(Tyr) side chains/aggregate strands': 0.004692383138113005},
#  {'alpha-helices': 0.2878501235806089,
#   'random coils': 0.349832704594213,
#   'turns': 0.04785897938535118,
#   'intermolecular beta_sheets (weak)': 0.0017131255433471024,
#   'aggregate beta-strand/beta_sheet': 0.3076531800371304,
#   '(Tyr) side chains/aggregate strands': 0.005091886859349409},
#  {'alpha-helices': 0.2883407038897891,
#   'random coils': 0.3514684043122915,
#   'turns': 0.04765503108312402,
#   'intermolecular beta_sheets (weak)': 0.0015074135188646038,
#   'aggregate beta-strand/beta_sheet': 0.30573360836985014,
#   '(Tyr) side chains/aggregate strands': 0.005294838826080531},
#  {'alpha-helices': 0.2879724472122309,
#   'random coils': 0.350322896450344,
#   'turns': 0.04763541433737517,
#   'intermolecular beta_sheets (weak)': 0.0014761895152568872,
#   'aggregate beta-strand/beta_sheet': 0.3072647291217951,
#   '(Tyr) side chains/aggregate strands': 0.005328323362997774},
#  {'alpha-helices': 0.28858637818413857,
#   'random coils': 0.34682612310920263,
#   'turns': 0.04722913328543444,
#   'intermolecular beta_sheets (weak)': 0.0014718015568553119,
#   'aggregate beta-strand/beta_sheet': 0.31087352682049163,
#   '(Tyr) side chains/aggregate strands': 0.005013037043877389},
#  {'alpha-helices': 0.28866622893349736,
#   'random coils': 0.34958821046584615,
#   'turns': 0.046773223386824145,
#   'intermolecular beta_sheets (weak)': 0.0015727604505651363,
#   'aggregate beta-strand/beta_sheet': 0.30812708232410846,
#   '(Tyr) side chains/aggregate strands': 0.005272494439158802},
#  {'alpha-helices': 0.288494695023058,
#   'random coils': 0.34789186810799255,
#   'turns': 0.04714645282431683,
#   'intermolecular beta_sheets (weak)': 0.0013610659823863876,
#   'aggregate beta-strand/beta_sheet': 0.3100944507388628,
#   '(Tyr) side chains/aggregate strands': 0.005011467323383303},
#  {'alpha-helices': 0.2921855494279461,
#   'random coils': 0.34788839108131664,
#   'turns': 0.049511136571876405,
#   'intermolecular beta_sheets (weak)': 0.001272723602973475,
#   'aggregate beta-strand/beta_sheet': 0.30370135060622394,
#   '(Tyr) side chains/aggregate strands': 0.005440848709663569},
#  {'alpha-helices': 0.2894499709877238,
#   'random coils': 0.35035153469359326,
#   'turns': 0.04704322825469418,
#   'intermolecular beta_sheets (weak)': 0.0010967633813528579,
#   'aggregate beta-strand/beta_sheet': 0.30660096905260714,
#   '(Tyr) side chains/aggregate strands': 0.005457533630028619},
#  {'alpha-helices': 0.2882496327672079,
#   'random coils': 0.35706119617050547,
#   'turns': 0.04998701594749924,
#   'intermolecular beta_sheets (weak)': 0.00142647744151086,
#   'aggregate beta-strand/beta_sheet': 0.2979871882393344,
#   '(Tyr) side chains/aggregate strands': 0.00528848943394215},
#  {'alpha-helices': 0.2886585455583478,
#   'random coils': 0.3516124607803997,
#   'turns': 0.04948229778373297,
#   'intermolecular beta_sheets (weak)': 0.0015320372329756017,
#   'aggregate beta-strand/beta_sheet': 0.30348960744663595,
#   '(Tyr) side chains/aggregate strands': 0.005225051197908075},
#  {'alpha-helices': 0.28061997853134446,
#   'random coils': 0.34729012680629356,
#   'turns': 0.04890990435078805,
#   'intermolecular beta_sheets (weak)': 0.0008949852669727491,
#   'aggregate beta-strand/beta_sheet': 0.3141013674432373,
#   '(Tyr) side chains/aggregate strands': 0.008183637601363876},
#  {'alpha-helices': 0.2885165237255537,
#   'random coils': 0.35571287043436073,
#   'turns': 0.047340048124891024,
#   'intermolecular beta_sheets (weak)': 0.0007789989387733617,
#   'aggregate beta-strand/beta_sheet': 0.30189514496559966,
#   '(Tyr) side chains/aggregate strands': 0.005756413810821614},
#  {'alpha-helices': 0.28904412279909164,
#   'random coils': 0.35460951374483385,
#   'turns': 0.047409711548487894,
#   'intermolecular beta_sheets (weak)': 0.0007228394631810417,
#   'aggregate beta-strand/beta_sheet': 0.3024638940802108,
#   '(Tyr) side chains/aggregate strands': 0.0057499183641947825},
#  {'alpha-helices': 0.2661401752702261,
#   'random coils': 0.30088864045945996,
#   'turns': 0.07130513436811853,
#   'intermolecular beta_sheets (weak)': 0.0007875182915049738,
#   'aggregate beta-strand/beta_sheet': 0.3363052020380684,
#   '(Tyr) side chains/aggregate strands': 0.024573329572622093},
#  {'alpha-helices': 0.2870594052546306,
#   'random coils': 0.34854136543123415,
#   'turns': 0.0459501276667309,
#   'intermolecular beta_sheets (weak)': 0.00035245162672304476,
#   'aggregate beta-strand/beta_sheet': 0.3105984769649083,
#   '(Tyr) side chains/aggregate strands': 0.007498173055773033},
#  {'alpha-helices': 0.28843141975344155,
#   'random coils': 0.35404757675920195,
#   'turns': 0.047176385056462655,
#   'intermolecular beta_sheets (weak)': 0.000784906992637905,
#   'aggregate beta-strand/beta_sheet': 0.30372473891914825,
#   '(Tyr) side chains/aggregate strands': 0.005834972519107694},
#  {'alpha-helices': 0.2903587344694603,
#   'random coils': 0.35030700513239316,
#   'turns': 0.0492778344389261,
#   'intermolecular beta_sheets (weak)': 0.0009034840018596258,
#   'aggregate beta-strand/beta_sheet': 0.303850394640125,
#   '(Tyr) side chains/aggregate strands': 0.0053025473172358725},
#  {'alpha-helices': 0.2876108251076052,
#   'random coils': 0.35991721120630815,
#   'turns': 0.04824716006724175,
#   'intermolecular beta_sheets (weak)': 0.0008014268059206295,
#   'aggregate beta-strand/beta_sheet': 0.2975758728888617,
#   '(Tyr) side chains/aggregate strands': 0.005847503924062568},
#  {'alpha-helices': 0.28821504200318315,
#   'random coils': 0.3578877321373564,
#   'turns': 0.04892498830619107,
#   'intermolecular beta_sheets (weak)': 0.0006494366032648642,
#   'aggregate beta-strand/beta_sheet': 0.29859974621242824,
#   '(Tyr) side chains/aggregate strands': 0.00572305473757654},
#  {'alpha-helices': 0.28930769037141557,
#   'random coils': 0.35628322780118177,
#   'turns': 0.050030171816225565,
#   'intermolecular beta_sheets (weak)': 0.0009467365592640548,
#   'aggregate beta-strand/beta_sheet': 0.2976928195506306,
#   '(Tyr) side chains/aggregate strands': 0.005739353901282468},
#  {'alpha-helices': 0.28709882186259406,
#   'random coils': 0.3596612617712246,
#   'turns': 0.050181400464711944,
#   'intermolecular beta_sheets (weak)': 0.001013015095947112,
#   'aggregate beta-strand/beta_sheet': 0.2963385552183908,
#   '(Tyr) side chains/aggregate strands': 0.005706945587131578},
#  {'alpha-helices': 0.28860299012788004,
#   'random coils': 0.35768749644350073,
#   'turns': 0.04982389134885691,
#   'intermolecular beta_sheets (weak)': 0.000962139792051436,
#   'aggregate beta-strand/beta_sheet': 0.29698722368161357,
#   '(Tyr) side chains/aggregate strands': 0.005936258606097302},
#  {'alpha-helices': 0.29086256363458335,
#   'random coils': 0.35697097764914604,
#   'turns': 0.04994376454709363,
#   'intermolecular beta_sheets (weak)': 0.0005697266923470815,
#   'aggregate beta-strand/beta_sheet': 0.2954068552639292,
#   '(Tyr) side chains/aggregate strands': 0.006246112212900798},
#  {'alpha-helices': 0.28901682538611695,
#   'random coils': 0.35677429462439997,
#   'turns': 0.0502172969217869,
#   'intermolecular beta_sheets (weak)': 0.0008515361520155814,
#   'aggregate beta-strand/beta_sheet': 0.29745488624929267,
#   '(Tyr) side chains/aggregate strands': 0.005685160666388034},
#  {'alpha-helices': 0.2888782855815004,
#   'random coils': 0.3657846640478254,
#   'turns': 0.050879682288448386,
#   'intermolecular beta_sheets (weak)': 0.0006392908365159583,
#   'aggregate beta-strand/beta_sheet': 0.2875554223859767,
#   '(Tyr) side chains/aggregate strands': 0.006262654859733351},
#  {'alpha-helices': 0.2903015248811733,
#   'random coils': 0.3585429986124506,
#   'turns': 0.050782237944438195,
#   'intermolecular beta_sheets (weak)': 0.0005825806318490274,
#   'aggregate beta-strand/beta_sheet': 0.2937262495509229,
#   '(Tyr) side chains/aggregate strands': 0.006064408379165794},
#  {'alpha-helices': 0.2895602087713168,
#   'random coils': 0.36170934396137433,
#   'turns': 0.052540916199275124,
#   'intermolecular beta_sheets (weak)': 0.0006675178876016204,
#   'aggregate beta-strand/beta_sheet': 0.28903475860628797,
#   '(Tyr) side chains/aggregate strands': 0.006487254574144292},
#  {'alpha-helices': 0.28849022417739567,
#   'random coils': 0.3632550386333473,
#   'turns': 0.05118600067584838,
#   'intermolecular beta_sheets (weak)': 0.0007974241263412551,
#   'aggregate beta-strand/beta_sheet': 0.2901748095110207,
#   '(Tyr) side chains/aggregate strands': 0.006096502876046695},
#  {'alpha-helices': 0.2940918254424096,
#   'random coils': 0.34960927523150437,
#   'turns': 0.05512458625093156,
#   'intermolecular beta_sheets (weak)': 0.0012686151113825972,
#   'aggregate beta-strand/beta_sheet': 0.29389784411461317,
#   '(Tyr) side chains/aggregate strands': 0.0060078538491586345},
#  {'alpha-helices': 0.2879240018197967,
#   'random coils': 0.3637124673190577,
#   'turns': 0.05114778077489012,
#   'intermolecular beta_sheets (weak)': 0.0006562450218418345,
#   'aggregate beta-strand/beta_sheet': 0.2904789478209127,
#   '(Tyr) side chains/aggregate strands': 0.006080557243501071},
#  {'alpha-helices': 0.3020806952137143,
#   'random coils': 0.32152058683532125,
#   'turns': 0.03194355467304875,
#   'intermolecular beta_sheets (weak)': 0.008058090740673755,
#   'aggregate beta-strand/beta_sheet': 0.3228711092775928,
#   '(Tyr) side chains/aggregate strands': 0.013525963259649212},
#  {'alpha-helices': 0.301073684940909,
#   'random coils': 0.3303785773618493,
#   'turns': 0.03145772606593249,
#   'intermolecular beta_sheets (weak)': 0.008304582725875448,
#   'aggregate beta-strand/beta_sheet': 0.3147683268151989,
#   '(Tyr) side chains/aggregate strands': 0.014017102090234728},
#  {'alpha-helices': 0.2870987116270755,
#   'random coils': 0.32767287048103316,
#   'turns': 0.03621332046548797,
#   'intermolecular beta_sheets (weak)': 0.010677991654125443,
#   'aggregate beta-strand/beta_sheet': 0.3241966346133636,
#   '(Tyr) side chains/aggregate strands': 0.014140471158914364},
#  {'alpha-helices': 0.2102355229042545,
#   'random coils': 0.35559560461426926,
#   'turns': 0.08511779806979786,
#   'intermolecular beta_sheets (weak)': 0.00034340904049295413,
#   'aggregate beta-strand/beta_sheet': 0.33141964965563536,
#   '(Tyr) side chains/aggregate strands': 0.017288015715550074},
#  {'alpha-helices': 0.27385953604785823,
#   'random coils': 0.3688874018772234,
#   'turns': 0.055618621871339737,
#   'intermolecular beta_sheets (weak)': 0.000338844097922404,
#   'aggregate beta-strand/beta_sheet': 0.2947885635852408,
#   '(Tyr) side chains/aggregate strands': 0.00650703252041549},
#  {'alpha-helices': 0.2888196979550925,
#   'random coils': 0.3657232999989194,
#   'turns': 0.053948422749129143,
#   'intermolecular beta_sheets (weak)': 0.0005515281898449089,
#   'aggregate beta-strand/beta_sheet': 0.2845116803223128,
#   '(Tyr) side chains/aggregate strands': 0.006445370784701126},
#  {'alpha-helices': 0.2870874139641626,
#   'random coils': 0.3680996980418942,
#   'turns': 0.05273087738011569,
#   'intermolecular beta_sheets (weak)': 0.0005772791283411582,
#   'aggregate beta-strand/beta_sheet': 0.2848384686437731,
#   '(Tyr) side chains/aggregate strands': 0.006666262841713124},
#  {'alpha-helices': 0.285579871186797,
#   'random coils': 0.37002953786922743,
#   'turns': 0.053337371471432235,
#   'intermolecular beta_sheets (weak)': 0.00042430093773485945,
#   'aggregate beta-strand/beta_sheet': 0.28421154374041285,
#   '(Tyr) side chains/aggregate strands': 0.006417374794395819},
#  {'alpha-helices': 0.2852884734047377,
#   'random coils': 0.37011054165362395,
#   'turns': 0.053784877334122475,
#   'intermolecular beta_sheets (weak)': 0.000245198066376231,
#   'aggregate beta-strand/beta_sheet': 0.28352728158482393,
#   '(Tyr) side chains/aggregate strands': 0.007043627956315785},
#  {'alpha-helices': 0.2622991763262381,
#   'random coils': 0.37579457380530407,
#   'turns': 0.06517775219118387,
#   'intermolecular beta_sheets (weak)': 0.00024599985009557515,
#   'aggregate beta-strand/beta_sheet': 0.2899237723745062,
#   '(Tyr) side chains/aggregate strands': 0.006558725452672103},
#  {'alpha-helices': 0.2900007094223875,
#   'random coils': 0.3665133195677384,
#   'turns': 0.052861329702451186,
#   'intermolecular beta_sheets (weak)': 0.0002228461881831326,
#   'aggregate beta-strand/beta_sheet': 0.2832442784819988,
#   '(Tyr) side chains/aggregate strands': 0.007157516637241138},
#  {'alpha-helices': 0.28828535321576687,
#   'random coils': 0.3666982299650318,
#   'turns': 0.051675857892123964,
#   'intermolecular beta_sheets (weak)': 0.00014216942727835624,
#   'aggregate beta-strand/beta_sheet': 0.2864584605514268,
#   '(Tyr) side chains/aggregate strands': 0.006739928948372128},
#  {'alpha-helices': 0.29080868061172116,
#   'random coils': 0.3627387119475364,
#   'turns': 0.04359392732378487,
#   'intermolecular beta_sheets (weak)': 0.007590403329384932,
#   'aggregate beta-strand/beta_sheet': 0.288539087637573,
#   '(Tyr) side chains/aggregate strands': 0.0067291891499994235},
#  {'alpha-helices': 0.2798485087570173,
#   'random coils': 0.37136228778439107,
#   'turns': 0.05539547993534743,
#   'intermolecular beta_sheets (weak)': 0.00022300749714370319,
#   'aggregate beta-strand/beta_sheet': 0.28644633679973486,
#   '(Tyr) side chains/aggregate strands': 0.006724379226365675},
#  {'alpha-helices': 0.29585406724069874,
#   'random coils': 0.3495364454631376,
#   'turns': 0.04452260796376506,
#   'intermolecular beta_sheets (weak)': 0.007171721859594725,
#   'aggregate beta-strand/beta_sheet': 0.2963927919735332,
#   '(Tyr) side chains/aggregate strands': 0.006522365499270599},
#  {'alpha-helices': 0.2773954943225326,
#   'random coils': 0.3648523559776176,
#   'turns': 0.056907903544934656,
#   'intermolecular beta_sheets (weak)': 5.403429683315725e-15,
#   'aggregate beta-strand/beta_sheet': 0.2940376475049038,
#   '(Tyr) side chains/aggregate strands': 0.006806598650005935},
#  {'alpha-helices': 0.2885412647191057,
#   'random coils': 0.3366431137909715,
#   'turns': 0.06529851494126686,
#   'intermolecular beta_sheets (weak)': 4.98310309483565e-05,
#   'aggregate beta-strand/beta_sheet': 0.3026313267792601,
#   '(Tyr) side chains/aggregate strands': 0.006835948738447569},
#  {'alpha-helices': 0.2990595592601068,
#   'random coils': 0.3426668217658904,
#   'turns': 0.03813397973894431,
#   'intermolecular beta_sheets (weak)': 0.008112172996310313,
#   'aggregate beta-strand/beta_sheet': 0.305425485680222,
#   '(Tyr) side chains/aggregate strands': 0.006601980558526205},
#  {'alpha-helices': 0.2969219676123749,
#   'random coils': 0.34631217104819817,
#   'turns': 0.03911174085857635,
#   'intermolecular beta_sheets (weak)': 0.0074260993002472605,
#   'aggregate beta-strand/beta_sheet': 0.30345091291635207,
#   '(Tyr) side chains/aggregate strands': 0.0067771082642512194},
#  {'alpha-helices': 0.2998121463673351,
#   'random coils': 0.3420517020258623,
#   'turns': 0.03460728747785267,
#   'intermolecular beta_sheets (weak)': 0.009197887668972301,
#   'aggregate beta-strand/beta_sheet': 0.3068121417743935,
#   '(Tyr) side chains/aggregate strands': 0.007518834685584055},
#  {'alpha-helices': 0.3023691154896973,
#   'random coils': 0.3258370891508278,
#   'turns': 0.03024848764342798,
#   'intermolecular beta_sheets (weak)': 0.009542744856050712,
#   'aggregate beta-strand/beta_sheet': 0.31850362544936417,
#   '(Tyr) side chains/aggregate strands': 0.013498937410631977},
#  {'alpha-helices': 0.3032512907734944,
#   'random coils': 0.3227826225401841,
#   'turns': 0.029673230961493102,
#   'intermolecular beta_sheets (weak)': 0.009624930294982051,
#   'aggregate beta-strand/beta_sheet': 0.31999057609036413,
#   '(Tyr) side chains/aggregate strands': 0.01467734933948222},
#  {'alpha-helices': 0.30193694474280836,
#   'random coils': 0.3258011558641134,
#   'turns': 0.031022105565524604,
#   'intermolecular beta_sheets (weak)': 0.009569763886491946,
#   'aggregate beta-strand/beta_sheet': 0.31556572832274793,
#   '(Tyr) side chains/aggregate strands': 0.01610430161831365},
#  {'alpha-helices': 0.30264920630588715,
#   'random coils': 0.3191208328384965,
#   'turns': 0.029399083545934592,
#   'intermolecular beta_sheets (weak)': 0.0098454585557819,
#   'aggregate beta-strand/beta_sheet': 0.3245285779640915,
#   '(Tyr) side chains/aggregate strands': 0.014456840789808412},
#  {'alpha-helices': 0.29907910867615045,
#   'random coils': 0.33867330165011794,
#   'turns': 0.03595424653761802,
#   'intermolecular beta_sheets (weak)': 0.009061659781053109,
#   'aggregate beta-strand/beta_sheet': 0.3104983821997298,
#   '(Tyr) side chains/aggregate strands': 0.00673330115533067},
#  {'alpha-helices': 0.2933095476479432,
#   'random coils': 0.36011095788229147,
#   'turns': 0.042857628067580436,
#   'intermolecular beta_sheets (weak)': 0.009308467242850563,
#   'aggregate beta-strand/beta_sheet': 0.28812023593566266,
#   '(Tyr) side chains/aggregate strands': 0.006293163223671687},
#  {'alpha-helices': 0.2992228781392678,
#   'random coils': 0.34037637721540825,
#   'turns': 0.03488346401553052,
#   'intermolecular beta_sheets (weak)': 0.00931586992549814,
#   'aggregate beta-strand/beta_sheet': 0.30872655615164524,
#   '(Tyr) side chains/aggregate strands': 0.007474854552650149},
#  {'alpha-helices': 0.300567619151606,
#   'random coils': 0.3359980382441357,
#   'turns': 0.033230236190057334,
#   'intermolecular beta_sheets (weak)': 0.009745700757268683,
#   'aggregate beta-strand/beta_sheet': 0.312190072944956,
#   '(Tyr) side chains/aggregate strands': 0.008268332711976417},
#  {'alpha-helices': 0.3006946490308327,
#   'random coils': 0.34099827550642786,
#   'turns': 0.03326008247265513,
#   'intermolecular beta_sheets (weak)': 0.010215154820672916,
#   'aggregate beta-strand/beta_sheet': 0.3065054219789022,
#   '(Tyr) side chains/aggregate strands': 0.0083264161905093},
#  {'alpha-helices': 0.30084896613403994,
#   'random coils': 0.3401774648191888,
#   'turns': 0.03364214938294204,
#   'intermolecular beta_sheets (weak)': 0.009540209846784865,
#   'aggregate beta-strand/beta_sheet': 0.30771414913496675,
#   '(Tyr) side chains/aggregate strands': 0.008077060682077662},
#  {'alpha-helices': 0.29983810929405874,
#   'random coils': 0.3377983592280754,
#   'turns': 0.034478978430027576,
#   'intermolecular beta_sheets (weak)': 0.009741512449778085,
#   'aggregate beta-strand/beta_sheet': 0.31068820118946433,
#   '(Tyr) side chains/aggregate strands': 0.007454839408596172},
#  {'alpha-helices': 0.2979841466294806,
#   'random coils': 0.3471376578098172,
#   'turns': 0.035747572771528485,
#   'intermolecular beta_sheets (weak)': 0.00913966007336105,
#   'aggregate beta-strand/beta_sheet': 0.30232130466503404,
#   '(Tyr) side chains/aggregate strands': 0.007669658050778466},
#  {'alpha-helices': 0.2999826136271675,
#   'random coils': 0.3428256590538422,
#   'turns': 0.03449157578556858,
#   'intermolecular beta_sheets (weak)': 0.010064337320452778,
#   'aggregate beta-strand/beta_sheet': 0.3046222676569936,
#   '(Tyr) side chains/aggregate strands': 0.008013546555975307},
#  {'alpha-helices': 0.3004251169074012,
#   'random coils': 0.34284894225303264,
#   'turns': 0.034851187092691575,
#   'intermolecular beta_sheets (weak)': 0.010431212024531376,
#   'aggregate beta-strand/beta_sheet': 0.304100037327154,
#   '(Tyr) side chains/aggregate strands': 0.007343504395189146},
#  {'alpha-helices': 0.3007034998896725,
#   'random coils': 0.3437655325741163,
#   'turns': 0.03525473907825639,
#   'intermolecular beta_sheets (weak)': 0.010387016225259822,
#   'aggregate beta-strand/beta_sheet': 0.3029255090371513,
#   '(Tyr) side chains/aggregate strands': 0.0069637031955434945},
#  {'alpha-helices': 0.3006202541465747,
#   'random coils': 0.3471370452698533,
#   'turns': 0.03629839660440721,
#   'intermolecular beta_sheets (weak)': 0.01021576263975878,
#   'aggregate beta-strand/beta_sheet': 0.2986135713752048,
#   '(Tyr) side chains/aggregate strands': 0.007114969964201025},
#  {'alpha-helices': 0.29755080568159187,
#   'random coils': 0.3503833520643862,
#   'turns': 0.03929562840917985,
#   'intermolecular beta_sheets (weak)': 0.008727928043350834,
#   'aggregate beta-strand/beta_sheet': 0.2972933359357863,
#   '(Tyr) side chains/aggregate strands': 0.006748949865704886},
#  {'alpha-helices': 0.30028418662198736,
#   'random coils': 0.34437378177111533,
#   'turns': 0.034704865333522586,
#   'intermolecular beta_sheets (weak)': 0.01365045269275975,
#   'aggregate beta-strand/beta_sheet': 0.30077574056146905,
#   '(Tyr) side chains/aggregate strands': 0.00621097301914579},
#  {'alpha-helices': 0.2787934152176864,
#   'random coils': 0.34259695917874816,
#   'turns': 0.077163862515367,
#   'intermolecular beta_sheets (weak)': 3.165692929874094e-05,
#   'aggregate beta-strand/beta_sheet': 0.2944210468926567,
#   '(Tyr) side chains/aggregate strands': 0.006993059266242977},
#  {'alpha-helices': 0.2714320623045108,
#   'random coils': 0.34558966517424816,
#   'turns': 0.08092619442834709,
#   'intermolecular beta_sheets (weak)': 1.2695424780545524e-05,
#   'aggregate beta-strand/beta_sheet': 0.29423140091255573,
#   '(Tyr) side chains/aggregate strands': 0.007807981755557722},
#  {'alpha-helices': 0.3017102497894046,
#   'random coils': 0.33544803253113237,
#   'turns': 0.028319240899817587,
#   'intermolecular beta_sheets (weak)': 0.012351607932071915,
#   'aggregate beta-strand/beta_sheet': 0.3087979884865579,
#   '(Tyr) side chains/aggregate strands': 0.013372880361015768},
#  {'alpha-helices': 0.30278479383747614,
#   'random coils': 0.3382320560841986,
#   'turns': 0.028732132495009284,
#   'intermolecular beta_sheets (weak)': 0.011184222994875296,
#   'aggregate beta-strand/beta_sheet': 0.3051609170090042,
#   '(Tyr) side chains/aggregate strands': 0.013905877579436628},
#  {'alpha-helices': 0.30330841733270253,
#   'random coils': 0.32928228950276067,
#   'turns': 0.02881540394927386,
#   'intermolecular beta_sheets (weak)': 0.01093724750741093,
#   'aggregate beta-strand/beta_sheet': 0.3128088943952842,
#   '(Tyr) side chains/aggregate strands': 0.014847747312567803},
#  {'alpha-helices': 0.3018615896124349,
#   'random coils': 0.33247442568376534,
#   'turns': 0.029168477491180053,
#   'intermolecular beta_sheets (weak)': 0.01099418369050707,
#   'aggregate beta-strand/beta_sheet': 0.31089144255374457,
#   '(Tyr) side chains/aggregate strands': 0.014609880968367907},
#  {'alpha-helices': 0.3009446166391685,
#   'random coils': 0.3398609599472838,
#   'turns': 0.03379415380387894,
#   'intermolecular beta_sheets (weak)': 0.010816456810336125,
#   'aggregate beta-strand/beta_sheet': 0.3068898213666338,
#   '(Tyr) side chains/aggregate strands': 0.007693991432698959},
#  {'alpha-helices': 0.2762750518149445,
#   'random coils': 0.3514855169386695,
#   'turns': 0.07992213263808025,
#   'intermolecular beta_sheets (weak)': 1.697246394524635e-05,
#   'aggregate beta-strand/beta_sheet': 0.28518926300502456,
#   '(Tyr) side chains/aggregate strands': 0.007111063139335978},
#  {'alpha-helices': 0.3000942664949037,
#   'random coils': 0.35494585779416854,
#   'turns': 0.03871372059814917,
# ...
#   'aggregate beta-strand/beta_sheet': 0.2728087347495076,
#   '(Tyr) side chains/aggregate strands': 0.007941360594006207},
#  {'alpha-helices': 0.30260974443320976,
#   'random coils': 0.35708316794841893,
#   'turns': 0.03861399112028848,
#   'intermolecular beta_sheets (weak)': 0.012613681693027361,
#   'aggregate beta-strand/beta_sheet': 0.28148652592485807,
#   '(Tyr) side chains/aggregate strands': 0.007592888880197355},
#  {'alpha-helices': 0.30251726776424764,
#   'random coils': 0.35604662214418137,
#   'turns': 0.037423798175084254,
#   'intermolecular beta_sheets (weak)': 0.014247900148580987,
#   'aggregate beta-strand/beta_sheet': 0.28276176577341894,
#   '(Tyr) side chains/aggregate strands': 0.007002645994486697},
#  {'alpha-helices': 0.3020622920812631,
#   'random coils': 0.35517663924744297,
#   'turns': 0.0386340006322637,
#   'intermolecular beta_sheets (weak)': 0.011996405767246142,
#   'aggregate beta-strand/beta_sheet': 0.2846708596362618,
#   '(Tyr) side chains/aggregate strands': 0.007459802635522413},
#  {'alpha-helices': 0.2990458308269813,
#   'random coils': 0.3584229363645566,
#   'turns': 0.03739791501214263,
#   'intermolecular beta_sheets (weak)': 0.013292720652398494,
#   'aggregate beta-strand/beta_sheet': 0.2844338121096852,
#   '(Tyr) side chains/aggregate strands': 0.0074067850342359924},
#  {'alpha-helices': 0.30183673867657157,
#   'random coils': 0.3497440657462576,
#   'turns': 0.03841479707589722,
#   'intermolecular beta_sheets (weak)': 0.011406450968597574,
#   'aggregate beta-strand/beta_sheet': 0.29193100338976347,
#   '(Tyr) side chains/aggregate strands': 0.00666694414291244},
#  {'alpha-helices': 0.30155031943426475,
#   'random coils': 0.3517833771077884,
#   'turns': 0.037921880373481515,
#   'intermolecular beta_sheets (weak)': 0.011196004515210054,
#   'aggregate beta-strand/beta_sheet': 0.2902904469062381,
#   '(Tyr) side chains/aggregate strands': 0.007257971663017115},
#  {'alpha-helices': 0.29861311946801095,
#   'random coils': 0.3576931385190035,
#   'turns': 0.0389305417576913,
#   'intermolecular beta_sheets (weak)': 0.010588521094095322,
#   'aggregate beta-strand/beta_sheet': 0.2863505350519172,
#   '(Tyr) side chains/aggregate strands': 0.007824144109282019},
#  {'alpha-helices': 0.302454028655906,
#   'random coils': 0.3459998826817077,
#   'turns': 0.03457030839499433,
#   'intermolecular beta_sheets (weak)': 0.01315560281884597,
#   'aggregate beta-strand/beta_sheet': 0.29595847396922487,
#   '(Tyr) side chains/aggregate strands': 0.007861703479321294},
#  {'alpha-helices': 0.30109409137297727,
#   'random coils': 0.3435196804650199,
#   'turns': 0.03634072065871346,
#   'intermolecular beta_sheets (weak)': 0.010812647044995394,
#   'aggregate beta-strand/beta_sheet': 0.301076277786269,
#   '(Tyr) side chains/aggregate strands': 0.007156582672024962},
#  {'alpha-helices': 0.30353569133101316,
#   'random coils': 0.3391554200417258,
#   'turns': 0.036442800355659694,
#   'intermolecular beta_sheets (weak)': 0.011742882536613179,
#   'aggregate beta-strand/beta_sheet': 0.30186731849273135,
#   '(Tyr) side chains/aggregate strands': 0.007255887242256787},
#  {'alpha-helices': 0.30031735908821505,
#   'random coils': 0.3461573843149197,
#   'turns': 0.035731531230377735,
#   'intermolecular beta_sheets (weak)': 0.010968799045152019,
#   'aggregate beta-strand/beta_sheet': 0.29924588147118225,
#   '(Tyr) side chains/aggregate strands': 0.007579044850153287},
#  {'alpha-helices': 0.29896552763263423,
#   'random coils': 0.3537270145094653,
#   'turns': 0.03865147564236893,
#   'intermolecular beta_sheets (weak)': 0.009988628216738762,
#   'aggregate beta-strand/beta_sheet': 0.2921661941834252,
#   '(Tyr) side chains/aggregate strands': 0.006501159815367481},
#  {'alpha-helices': 0.27752304886879664,
#   'random coils': 0.35246908293885393,
#   'turns': 0.07896256174320589,
#   'intermolecular beta_sheets (weak)': 6.793885462904231e-06,
#   'aggregate beta-strand/beta_sheet': 0.2833882922405857,
#   '(Tyr) side chains/aggregate strands': 0.007650220323094734},
#  {'alpha-helices': 0.30124325705293503,
#   'random coils': 0.3418073568788547,
#   'turns': 0.031982122342668624,
#   'intermolecular beta_sheets (weak)': 0.010585628286131967,
#   'aggregate beta-strand/beta_sheet': 0.3026914837197539,
#   '(Tyr) side chains/aggregate strands': 0.011690151719655626},
#  {'alpha-helices': 0.3033351367040558,
#   'random coils': 0.3371330196839098,
#   'turns': 0.032771134970403154,
#   'intermolecular beta_sheets (weak)': 0.010348864086604747,
#   'aggregate beta-strand/beta_sheet': 0.30603907223935534,
#   '(Tyr) side chains/aggregate strands': 0.01037277231567098},
#  {'alpha-helices': 0.303452153225842,
#   'random coils': 0.3260440549806409,
#   'turns': 0.028948479873652695,
#   'intermolecular beta_sheets (weak)': 0.010216867665655438,
#   'aggregate beta-strand/beta_sheet': 0.3176266578503085,
#   '(Tyr) side chains/aggregate strands': 0.013711786403900372},
#  {'alpha-helices': 0.30189031155709106,
#   'random coils': 0.33004969169941945,
#   'turns': 0.029346018335602596,
#   'intermolecular beta_sheets (weak)': 0.010240446778006304,
#   'aggregate beta-strand/beta_sheet': 0.31475650176441305,
#   '(Tyr) side chains/aggregate strands': 0.013717029865467713},
#  {'alpha-helices': 0.30309372699924075,
#   'random coils': 0.32756055105285625,
#   'turns': 0.02934662592378467,
#   'intermolecular beta_sheets (weak)': 0.010290577504222683,
#   'aggregate beta-strand/beta_sheet': 0.3157280856283666,
#   '(Tyr) side chains/aggregate strands': 0.013980432891529131},
#  {'alpha-helices': 0.30136289885660206,
#   'random coils': 0.3270806045884044,
#   'turns': 0.03124766613885442,
#   'intermolecular beta_sheets (weak)': 0.009530795340219821,
#   'aggregate beta-strand/beta_sheet': 0.3199657167075126,
#   '(Tyr) side chains/aggregate strands': 0.010812318368406524},
#  {'alpha-helices': 0.30047226951226325,
#   'random coils': 0.33226071900366433,
#   'turns': 0.028642663217501103,
#   'intermolecular beta_sheets (weak)': 0.01262968438452189,
#   'aggregate beta-strand/beta_sheet': 0.31545766645622564,
#   '(Tyr) side chains/aggregate strands': 0.01053699742582356},
#  {'alpha-helices': 0.3014274807014275,
#   'random coils': 0.32958739879267046,
#   'turns': 0.031279655686934006,
#   'intermolecular beta_sheets (weak)': 0.009338153126770074,
#   'aggregate beta-strand/beta_sheet': 0.3168092967268324,
#   '(Tyr) side chains/aggregate strands': 0.011558014965365336},
#  {'alpha-helices': 0.30010407420503493,
#   'random coils': 0.3306618754900728,
#   'turns': 0.03212421095668581,
#   'intermolecular beta_sheets (weak)': 0.008994276145694195,
#   'aggregate beta-strand/beta_sheet': 0.31759980638750646,
#   '(Tyr) side chains/aggregate strands': 0.01051575681500598},
#  {'alpha-helices': 0.30093556649092745,
#   'random coils': 0.33245278983078,
#   'turns': 0.03140313582550537,
#   'intermolecular beta_sheets (weak)': 0.009885416739705263,
#   'aggregate beta-strand/beta_sheet': 0.31208203165456616,
#   '(Tyr) side chains/aggregate strands': 0.013241059458515624},
#  {'alpha-helices': 0.30081215139206535,
#   'random coils': 0.33400490893838075,
#   'turns': 0.03239700660046427,
#   'intermolecular beta_sheets (weak)': 0.008992219535083735,
#   'aggregate beta-strand/beta_sheet': 0.31388893850515776,
#   '(Tyr) side chains/aggregate strands': 0.009904775028848295},
#  {'alpha-helices': 0.3012744765624021,
#   'random coils': 0.3330397431646285,
#   'turns': 0.03327645669942958,
#   'intermolecular beta_sheets (weak)': 0.00888486211404452,
#   'aggregate beta-strand/beta_sheet': 0.31453792994282326,
#   '(Tyr) side chains/aggregate strands': 0.008986531516672029},
#  {'alpha-helices': 0.29922411690852063,
#   'random coils': 0.33432806169450213,
#   'turns': 0.0353088771991243,
#   'intermolecular beta_sheets (weak)': 0.007882840642780315,
#   'aggregate beta-strand/beta_sheet': 0.3155715240965805,
#   '(Tyr) side chains/aggregate strands': 0.007684579458492412},
#  {'alpha-helices': 0.2567267131514289,
#   'random coils': 0.3636053562874241,
#   'turns': 0.06394608290764359,
#   'intermolecular beta_sheets (weak)': 7.413944824139646e-26,
#   'aggregate beta-strand/beta_sheet': 0.30839781513997383,
#   '(Tyr) side chains/aggregate strands': 0.007324032513529612},
#  {'alpha-helices': 0.25460459469548546,
#   'random coils': 0.37014040673843807,
#   'turns': 0.06529411835877093,
#   'intermolecular beta_sheets (weak)': 0.00037720588929325316,
#   'aggregate beta-strand/beta_sheet': 0.3028844869987856,
#   '(Tyr) side chains/aggregate strands': 0.006699187319226517},
#  {'alpha-helices': 0.27189670562630586,
#   'random coils': 0.3603692834295568,
#   'turns': 0.05702887128728622,
#   'intermolecular beta_sheets (weak)': 0.00034624283509630707,
#   'aggregate beta-strand/beta_sheet': 0.30426990649879404,
#   '(Tyr) side chains/aggregate strands': 0.006088990322960735},
#  {'alpha-helices': 0.2755618994044026,
#   'random coils': 0.3626322924896178,
#   'turns': 0.05577384152545331,
#   'intermolecular beta_sheets (weak)': 0.0003323617021957346,
#   'aggregate beta-strand/beta_sheet': 0.29933335559656027,
#   '(Tyr) side chains/aggregate strands': 0.006366249281770273},
#  {'alpha-helices': 0.28548803930851324,
#   'random coils': 0.3579971410912431,
#   'turns': 0.051199200498131175,
#   'intermolecular beta_sheets (weak)': 0.000316979372055758,
#   'aggregate beta-strand/beta_sheet': 0.29870917583176826,
#   '(Tyr) side chains/aggregate strands': 0.006289463898288271},
#  {'alpha-helices': 0.2894437673621354,
#   'random coils': 0.36684263526189986,
#   'turns': 0.05184021054955324,
#   'intermolecular beta_sheets (weak)': 0.0002793518407599271,
#   'aggregate beta-strand/beta_sheet': 0.28481297289478064,
#   '(Tyr) side chains/aggregate strands': 0.006781062090870951},
#  {'alpha-helices': 0.274638766738451,
#   'random coils': 0.3720646453230601,
#   'turns': 0.0599496265034853,
#   'intermolecular beta_sheets (weak)': 0.0007492725967858981,
#   'aggregate beta-strand/beta_sheet': 0.2858455213614167,
#   '(Tyr) side chains/aggregate strands': 0.006752167476800962},
#  {'alpha-helices': 0.25177870710994815,
#   'random coils': 0.3576287480855856,
#   'turns': 0.0646414203273068,
#   'intermolecular beta_sheets (weak)': 0.0003444222969601852,
#   'aggregate beta-strand/beta_sheet': 0.3170762304986681,
#   '(Tyr) side chains/aggregate strands': 0.008530471681531097},
#  {'alpha-helices': 0.29152020439374515,
#   'random coils': 0.3629434716449788,
#   'turns': 0.05520880014038889,
#   'intermolecular beta_sheets (weak)': 0.0009917743099830104,
#   'aggregate beta-strand/beta_sheet': 0.28291587202888335,
#   '(Tyr) side chains/aggregate strands': 0.0064198774820207125},
#  {'alpha-helices': 0.20349585141728394,
#   'random coils': 0.3637657010309711,
#   'turns': 0.0881871198079627,
#   'intermolecular beta_sheets (weak)': 0.0004852602735266971,
#   'aggregate beta-strand/beta_sheet': 0.3256467533004521,
#   '(Tyr) side chains/aggregate strands': 0.01841931416980349},
#  {'alpha-helices': 0.19447854273719323,
#   'random coils': 0.36819263536792135,
#   'turns': 0.09280998459192297,
#   'intermolecular beta_sheets (weak)': 0.0005153620795853551,
#   'aggregate beta-strand/beta_sheet': 0.3275911879504749,
#   '(Tyr) side chains/aggregate strands': 0.016412287272902427},
#  {'alpha-helices': 0.202867379123658,
#   'random coils': 0.363295050762142,
#   'turns': 0.08888390631509845,
#   'intermolecular beta_sheets (weak)': 0.0006036239653884789,
#   'aggregate beta-strand/beta_sheet': 0.3303930165007463,
#   '(Tyr) side chains/aggregate strands': 0.01395702333296681},
#  {'alpha-helices': 0.2896219877854875,
#   'random coils': 0.3642341414279717,
#   'turns': 0.05342239173886232,
#   'intermolecular beta_sheets (weak)': 0.001293342303837189,
#   'aggregate beta-strand/beta_sheet': 0.2852806126747537,
#   '(Tyr) side chains/aggregate strands': 0.006147524069087594},
#  {'alpha-helices': 0.2906732574937171,
#   'random coils': 0.36175329687573043,
#   'turns': 0.053013540134887925,
#   'intermolecular beta_sheets (weak)': 0.001060986400245086,
#   'aggregate beta-strand/beta_sheet': 0.2875538510921849,
#   '(Tyr) side chains/aggregate strands': 0.005945068003234761},
#  {'alpha-helices': 0.29375904598773106,
#   'random coils': 0.3562846056526016,
#   'turns': 0.05613663090580821,
#   'intermolecular beta_sheets (weak)': 0.0014183344770371585,
#   'aggregate beta-strand/beta_sheet': 0.286811266876662,
#   '(Tyr) side chains/aggregate strands': 0.0055901161001601744},
#  {'alpha-helices': 0.29124728806004047,
#   'random coils': 0.35750532389957307,
#   'turns': 0.053588130690768974,
#   'intermolecular beta_sheets (weak)': 0.0012620276924989226,
#   'aggregate beta-strand/beta_sheet': 0.2903400903411198,
#   '(Tyr) side chains/aggregate strands': 0.006057139315998794},
#  {'alpha-helices': 0.29087647399264616,
#   'random coils': 0.3591466733520004,
#   'turns': 0.05188697500181641,
#   'intermolecular beta_sheets (weak)': 0.0013176554160199679,
#   'aggregate beta-strand/beta_sheet': 0.2910164586977582,
#   '(Tyr) side chains/aggregate strands': 0.005755763539758901},
#  {'alpha-helices': 0.28991034900032636,
#   'random coils': 0.36348318511320926,
#   'turns': 0.05214978848175272,
#   'intermolecular beta_sheets (weak)': 0.0012187959410412937,
#   'aggregate beta-strand/beta_sheet': 0.2872962772286622,
#   '(Tyr) side chains/aggregate strands': 0.005941604235008112},
#  {'alpha-helices': 0.2895160789753598,
#   'random coils': 0.36306385031557514,
#   'turns': 0.05247799512247764,
#   'intermolecular beta_sheets (weak)': 0.0012994742495224683,
#   'aggregate beta-strand/beta_sheet': 0.28771301991303855,
#   '(Tyr) side chains/aggregate strands': 0.005929581424026302},
#  {'alpha-helices': 0.28893852540884035,
#   'random coils': 0.36171040648283265,
#   'turns': 0.05207432272542568,
#   'intermolecular beta_sheets (weak)': 0.0013988774643364896,
#   'aggregate beta-strand/beta_sheet': 0.2900651290120168,
#   '(Tyr) side chains/aggregate strands': 0.005812738906547901},
#  {'alpha-helices': 0.2897315425424975,
#   'random coils': 0.3623907443324945,
#   'turns': 0.05145754560135732,
#   'intermolecular beta_sheets (weak)': 0.0014400462200412111,
#   'aggregate beta-strand/beta_sheet': 0.2889868087395024,
#   '(Tyr) side chains/aggregate strands': 0.005993312564107126},
#  {'alpha-helices': 0.2946075289978597,
#   'random coils': 0.3456337577024811,
#   'turns': 0.05358380798450636,
#   'intermolecular beta_sheets (weak)': 0.0013792172431228433,
#   'aggregate beta-strand/beta_sheet': 0.2998729733710523,
#   '(Tyr) side chains/aggregate strands': 0.004922714700977663},
#  {'alpha-helices': 0.28959556534904707,
#   'random coils': 0.3582570881109107,
#   'turns': 0.0511886998670039,
#   'intermolecular beta_sheets (weak)': 0.0013961017208233277,
#   'aggregate beta-strand/beta_sheet': 0.29400948669393073,
#   '(Tyr) side chains/aggregate strands': 0.0055530582582842105},
#  {'alpha-helices': 0.290113256731776,
#   'random coils': 0.3576194373921361,
#   'turns': 0.050560678677418085,
#   'intermolecular beta_sheets (weak)': 0.0014033548345222377,
#   'aggregate beta-strand/beta_sheet': 0.2946443425259257,
#   '(Tyr) side chains/aggregate strands': 0.005658929838221828},
#  {'alpha-helices': 0.289867545574331,
#   'random coils': 0.35939470204276963,
#   'turns': 0.050861272940040364,
#   'intermolecular beta_sheets (weak)': 0.0011706453942650764,
#   'aggregate beta-strand/beta_sheet': 0.2930805069067903,
#   '(Tyr) side chains/aggregate strands': 0.005625327141803665},
#  {'alpha-helices': 0.2879606451193326,
#   'random coils': 0.3596514279513008,
#   'turns': 0.05059419848089808,
#   'intermolecular beta_sheets (weak)': 0.0012907910668050239,
#   'aggregate beta-strand/beta_sheet': 0.29489043009285454,
#   '(Tyr) side chains/aggregate strands': 0.005612507288808824},
#  {'alpha-helices': 0.2878673846380109,
#   'random coils': 0.35711157523114123,
#   'turns': 0.048556695382590484,
#   'intermolecular beta_sheets (weak)': 0.0014442775158547557,
#   'aggregate beta-strand/beta_sheet': 0.2994581350113173,
#   '(Tyr) side chains/aggregate strands': 0.005561932221085499},
#  {'alpha-helices': 0.2879226785120819,
#   'random coils': 0.34381417319764046,
#   'turns': 0.04431342861123744,
#   'intermolecular beta_sheets (weak)': 0.0008220684177868946,
#   'aggregate beta-strand/beta_sheet': 0.3152657939198352,
#   '(Tyr) side chains/aggregate strands': 0.007861857341418031}]

# %%
# index = 1
# sample = corrected_df.columns[index]
# print("Analyzing {}".format(corrected_df.columns[index]))
# area, res = gaussian_least_squares(corrected_df, corrected_df.columns[index], peak_width=15, 
#                                    peaks=six_peak, params={'loss':'linear'})
# structs = secondary_structure(area, six_peak)
# gaussian_list_data = gaussian_list(corrected_df['wavenumber'], *res.x)
# plt = create_fit_plots(corrected_df, sample, gaussian_list_data)
# plt.show()
# print(structs)

# %% [markdown]
# Attempt to compare area of beta sheet vs random coils out

# %%
ratio_1 = []
ratio_2 = []
for i in range(0,len(structs)):
    ratio_1.append(structs[i]['aggregate beta-strand/beta_sheet'] + structs[i]['intermolecular beta_sheets (weak)'])
    #ratio_2.append(structs[i]['aggregate beta-strand/beta_sheet']+structs[i]['intermolecular beta_sheets (weak)'])/(structs[i]['alpha-helices']+structs[i]['random coils']+structs[i]['turns']+structs[i]['(Tyr) side chains/aggregate strands']+structs[i]['aggregate beta-strand/beta_sheet']+structs[i]['intermolecular beta_sheets (weak)'])

# %%
len(ratio_1)
# Out:
# 399

# %%
plt.plot(ratio_1)

# %%
# (structs['aggregate beta-strand/beta_sheet']+structs['intermolecular beta_sheets (weak)']) # ANSWER FOR ONE COLUMN NEEDED FOR ALL

# %%
# structs['random coils']

# %%
import seaborn as sns

# %%
break_ratio_1 = np.array_split(np.array(ratio_1),25)

# %%
break_ratio_1[0:1]
# Out:
# [array([0.27345179, 0.27921129, 0.27629913, 0.28742043, 0.28017329,
#         0.28094709, 0.29077754, 0.28429729, 0.2794031 , 0.27870584,
#         0.28090504, 0.28281818, 0.33730646, 0.29081294, 0.3366213 ,
#         0.28878071])]

# %%
ax_example = sns.heatmap(break_ratio_1[0:1])

ax_example.invert_yaxis()

# %%
ax = sns.heatmap(break_ratio_1[0:24])
ax.invert_yaxis()

# %%
len(break_ratio_1)
# Out:
# 25

# %%
ratio_subsection = [ratio_1[0:25], ratio_1[25:50]]

# %%
sns.heatmap(ratio_subsection)
# Out:
# <AxesSubplot:>

# %%
sns.heat
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2184/1419947257.py in <module>
# ----> 1 sns.heat
#
# AttributeError: module 'seaborn' has no attribute 'heat'

# %%
pd.DataFrame(ratio_1[1:21]).corr()
# Out:
#      0
# 0  1.0

# %% [markdown]
# ## Peak fitting results

# %%
from copy import deepcopy
new_peaks = deepcopy(yang_h20_2015)
new_peaks['means'].append(1610)
new_peaks['assignments'].append('side-chain')
new_peaks['uncertainties'].append((1606, 1616))
new_peaks['relative_uncertainties'].append(4)

# %%
index = 1
sample = corrected_df.columns[index]
print("Analyzing {}".format(corrected_df.columns[index]))
area, res = gaussian_least_squares(corrected_df, corrected_df.columns[index], peak_width=1.5, peaks=new_peaks)
structs = secondary_structure(area, new_peaks)
gaussian_list_data = gaussian_list(corrected_df['freq'], *res.x)
plt = create_fit_plots(corrected_df, sample, gaussian_list_data)
plt.show()
print(structs)

# %%
###SKIPPING bc derivative not needed


#2nd derivative data from original spectra
#need to figure out how the indexing works as taking differences means we lose one value in the x-dimension (wavenumber) here
corrected_df['wavenumber']
corrected_df_1stDerivative = np.diff(corrected_df['1,1'])/np.diff(corrected_df['wavenumber'])
corrected_df_2ndDerivative = np.diff(corrected_df_1stDerivative)/np.diff(corrected_df['wavenumber'][0:90])

#corrected_df_2ndDerivative = np.diff(corrected_df, 2)
#print(corrected_df_2ndDerivative)
# #print(corrected_df_1stDerivative)
# print(corrected_df_1stDerivative)
# print(corrected_df_2ndDerivative)
# type(corrected_df_1stDerivative)
#corrected_df['wavenumber']

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(211)
ax.plot(corrected_df['wavenumber'][1:91], corrected_df_1stDerivative, label='$1^{st}$ derivative')
ax.plot(corrected_df['wavenumber'][1:90], corrected_df_2ndDerivative, label='$2^{nd}$ derivative')
ax.legend(loc=1)




#
# # corrected_df_2ndDerivative = corrected_df.derivative(n=2)
# from scipy.interpolate import UnivariateSpline

# y_spl = UnivariateSpline(x,y,s=0,k=4)
# #plt.plot(x_range,y_spl_2d(x_range))
